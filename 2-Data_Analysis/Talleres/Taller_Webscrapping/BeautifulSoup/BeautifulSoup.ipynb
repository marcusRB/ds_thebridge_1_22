# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página de libros más vendidos de Book Depository, y para lograr esto, también tendrá que hacer uso de un poco de pandas principalmente..

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# !pip install beautifulsoup4

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parswer, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# !pip install lxml

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# !pip install requests

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from splinter import Browser
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.bookdepository.com/bestsellers"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
# print(html)

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los libros más vendidos)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="See our top 1000 bestselling books, charts and future bestsellers. Free delivery worldwide on over 20 million books at Book Depository." name="description"/>
# <meta content="top 1000,bestseller,book,featured,chart,future bestsellers,free delivery worldwide,books" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <link href="https://www.bookdepository.com/bestsellers" rel="canonical"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/bestsellers" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/bestsellers" hreflang="es" rel="alternate"/>
# <link href="/bestsellers?page=2" rel="next"/>
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <link href="https://fonts.googleapis.com/css?family=Roboto" onload="csmWidgetEnd('font-download');" rel="stylesheet"/>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="">
# <div class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>We use cookies to improve this site</h2>
# <p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. You can learn more about our use of cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a></p><h2>Are you happy to accept cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Yes</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Manage cookies</a>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Cookie Preferences</h2>
# <p>We use cookies and similar tools that are necessary to enable you to make purchases, including those used by approved third parties (collectively, "cookies") for the purposes described below.
#      <br/>You can learn more about how we (plus approved third parties) use cookies and how to change your settings by visiting the <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>. The choices you make here will apply to your interaction with this service on this device.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Essential</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>We use cookies to provide our services, </span>
# <div>
# <div class="additionalInfo wrapping-space"> for example, to keep track of items stored in your shopping basket, prevent fraudulent activity, improve the security of our services, keep track of your specific preferences (such as currency or language preferences), and display features, products and services that might be of interest to you. Because we use cookies to provide you our services, they cannot be disabled when used for these purposes.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Performance and Analytics</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to understand how customers use our services</span>
# <div>
# <div class="additionalInfo wrapping-space"> (for example, by measuring site visits) so we can make improvements.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Advertising</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to complement your shopping experience, as described in our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a></span>
# <div>
# <div class="additionalInfo wrapping-space"> and serve you certain types of ads relevant to your interests on Book Depository. This includes using third party cookies for the purpose of displaying and measuring ads (see the <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a> notice for how we use cookies in serving interest-based ads), measuring the effectiveness of ads, and as necessary for the third party to perform services on behalf of Book Depository.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                 Cancel</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Save settings</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a></li>
# <li class="mob-nav-account"><a href="/contactus"><i class="icon-em"></i>Contact us</a></li>
# <li class="mob-nav-account"><a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a></li>
# <li class="mob-nav-account"><a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a></li>
# <li class="mob-nav-account"><a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Search for books by keyword / title / author / ISBN" class="text-input" name="searchTerm" placeholder="Search for books by keyword / title / author / ISBN" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Search</span></button>
# </div>
# </form>
# <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>All Categories</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Browse All</a></li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/category/2/Art-Photography">
#                                     Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/category/3389/Audio-Books">
#                                     Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/213/Biography">
#                                     Biography</a>
# </li>
# <li data-order="0">
# <a href="/category/928/Business-Finance-Law">
#                                     Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2455/Childrens-Books">
#                                     Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/category/1897/Computing">
#                                     Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2942/Crafts-Hobbies">
#                                     Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2616/Crime-Thriller">
#                                     Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/category/240/Dictionaries-Languages">
#                                     Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/category/3245/Entertainment">
#                                     Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/333/Fiction">
#                                     Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2858/Food-Drink">
#                                     Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                     Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/category/2770/Health">
#                                     Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2638/History-Archaeology">
#                                     History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/category/2892/Home-Garden">
#                                     Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/category/2978/Humour">
#                                     Humour</a>
# </li>
# <li data-order="0">
# <a href="/category/1279/Medical">
#                                     Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2819/Mind-Body-Spirit">
#                                     Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/category/2985/Natural-History">
#                                     Natural History</a>
# </li>
# <li data-order="0">
# <a href="/category/2802/Personal-Development">
#                                     Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/category/283/Poetry-Drama">
#                                     Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/category/375/Reference">
#                                     Reference</a>
# </li>
# <li data-order="0">
# <a href="/category/3120/Religion">
#                                     Religion</a>
# </li>
# <li data-order="0">
# <a href="/category/2630/Romance">
#                                     Romance</a>
# </li>
# <li data-order="0">
# <a href="/category/1476/Science-Geography">
#                                     Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                     Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/category/632/Society-Social-Sciences">
#                                     Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/category/3013/Sport">
#                                     Sport</a>
# </li>
# <li data-order="0">
# <a href="/category/3385/Stationery">
#                                     Stationery</a>
# </li>
# <li data-order="0">
# <a href="/category/3328/Teaching-Resources-Education">
#                                     Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/category/1708/Technology-Engineering">
#                                     Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/category/3391/Teen-Young-Adult">
#                                     Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/category/2967/Transport">
#                                     Transport</a>
# </li>
# <li data-order="0">
# <a href="/category/3098/Travel-Holiday-Guides">
#                                     Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Children's books by age range</p></li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/category/3392/Books-for-Ages-0-2">
#                           Ages 0-2</a>
# </li>
# <li>
# <a href="/category/3393/Books-for-Ages-3-5">
#                           Ages 3-5</a>
# </li>
# <li>
# <a href="/category/3394/Books-for-Ages-6-8">
#                           Ages 6-8</a>
# </li>
# <li>
# <a href="/category/3395/Books-for-Ages-9-11">
#                           Ages 9-11</a>
# </li>
# <li>
# <a href="/category/3391/Teen-Young-Adult">
#                           Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/bestsellers">Bestsellers</a></li>
# <li class="mob-nav-shop"><a href="/comingsoon">Coming Soon</a></li><li class="mob-nav-shop"><a href="/top-new-releases">New Releases</a></li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         English</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Languages</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             English</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Spanish (Español)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="English">
# <select id="selectLanguage" name="selectLanguage">
# <option selected="selected" value="en_US">
#                     English</option>
# <option value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div class="sidebar">
# <div class="sidebar-section search-filter">
# <h2>Filter your search</h2>
# <div class="sidebar-section-content search-filter-sidebar">
# <form action="/bestsellers" class="filter-menu" method="get">
# <div class="form-group">
# <label for="searchTerm">Keyword</label>
# <input class="form-control" name="searchTerm" type="text" value=""/>
# </div>
# <input name="searchSortBy" type="hidden" value=""/>
# <input name="category" type="hidden" value=""/>
# <div class="form-group">
# <label for="filter_price">Price range</label>
# <select class="form-control" id="filterPrice" name="price">
# <option label="All" value="">
# 							All</option>
# <option label="Under €15" value="low">
# 							Under €15</option>
# <option label="€15 to €30" value="med">
# 							€15 to €30</option>
# <option label="€30 +" value="high">
# 							€30 +</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_availability">Availability</label>
# <select class="form-control" id="filterAvailability" name="availability">
# <option label="All" value="">
# 							All</option>
# <option label="In stock (71707)" value="1">
# 							In stock (71707)</option>
# <option label="Pre-order (2815)" value="2">
# 							Pre-order (2815)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="filter_search_lang">Language</label>
# <select class="form-control" id="filterLang" name="searchLang">
# <option label="All" value="">
# 							All</option>
# <option label="English (69016)" value="123">
# 							English (69016)</option>
# <option label="French (362)" value="137">
# 							French (362)</option>
# <option label="Spanish (2367)" value="404">
# 							Spanish (2367)</option>
# <option label="German (1230)" value="150">
# 							German (1230)</option>
# <option label="Latin (32)" value="246">
# 							Latin (32)</option>
# <option label="Italian (180)" value="202">
# 							Italian (180)</option>
# <option label="Chinese (425)" value="79">
# 							Chinese (425)</option>
# <option label="Russian (25)" value="365">
# 							Russian (25)</option>
# <option label="Japanese (78)" value="205">
# 							Japanese (78)</option>
# <option label="Dutch; Flemish (4)" value="116">
# 							Dutch; Flemish (4)</option>
# <option label="Afar (1)" value="1">
# 							Afar (1)</option>
# <option label="Afrikaans (5)" value="9">
# 							Afrikaans (5)</option>
# <option label="Ainu (1)" value="10">
# 							Ainu (1)</option>
# <option label="Arabic (49)" value="21">
# 							Arabic (49)</option>
# <option label="Basque (1)" value="44">
# 							Basque (1)</option>
# <option label="Bulgarian (4)" value="65">
# 							Bulgarian (4)</option>
# <option label="Catalan (18)" value="71">
# 							Catalan (18)</option>
# <option label="Cree (1)" value="96">
# 							Cree (1)</option>
# <option label="Czech (2)" value="101">
# 							Czech (2)</option>
# <option label="Danish (1)" value="103">
# 							Danish (1)</option>
# <option label="English, Old (ca. 450-1100) (1)" value="18">
# 							English, Old (ca. 450-1100) (1)</option>
# <option label="Esperanto (1)" value="125">
# 							Esperanto (1)</option>
# <option label="Estonian (1)" value="126">
# 							Estonian (1)</option>
# <option label="Finnish (37)" value="134">
# 							Finnish (37)</option>
# <option label="Georgian (1)" value="149">
# 							Georgian (1)</option>
# <option label="Greek, Ancient (to 1453) (11)" value="163">
# 							Greek, Ancient (to 1453) (11)</option>
# <option label="Greek, Modern (1453-) (14)" value="164">
# 							Greek, Modern (1453-) (14)</option>
# <option label="Hebrew (5)" value="173">
# 							Hebrew (5)</option>
# <option label="Hindi (2)" value="177">
# 							Hindi (2)</option>
# <option label="Hungarian (5)" value="183">
# 							Hungarian (5)</option>
# <option label="Irish (9)" value="154">
# 							Irish (9)</option>
# <option label="Korean (108)" value="231">
# 							Korean (108)</option>
# <option label="Mandar (1)" value="276">
# 							Mandar (1)</option>
# <option label="Maori (2)" value="270">
# 							Maori (2)</option>
# <option label="Multiple languages (15)" value="292">
# 							Multiple languages (15)</option>
# <option label="Nepali (1)" value="308">
# 							Nepali (1)</option>
# <option label="No linguistic content (6)" value="486">
# 							No linguistic content (6)</option>
# <option label="Norwegian (4)" value="317">
# 							Norwegian (4)</option>
# <option label="Persian (1)" value="343">
# 							Persian (1)</option>
# <option label="Polish (338)" value="347">
# 							Polish (338)</option>
# <option label="Portuguese (111)" value="349">
# 							Portuguese (111)</option>
# <option label="Romanian (3)" value="362">
# 							Romanian (3)</option>
# <option label="Sanskrit (3)" value="372">
# 							Sanskrit (3)</option>
# <option label="Scots (7)" value="377">
# 							Scots (7)</option>
# <option label="Scottish Gaelic (9)" value="153">
# 							Scottish Gaelic (9)</option>
# <option label="Serbian (1)" value="375">
# 							Serbian (1)</option>
# <option label="Slovak (1)" value="388">
# 							Slovak (1)</option>
# <option label="Slovenian (2)" value="389">
# 							Slovenian (2)</option>
# <option label="Swedish (115)" value="415">
# 							Swedish (115)</option>
# <option label="Tagalog (1)" value="427">
# 							Tagalog (1)</option>
# <option label="Tamil (1)" value="420">
# 							Tamil (1)</option>
# <option label="Thai (2)" value="428">
# 							Thai (2)</option>
# <option label="Turkish (2)" value="446">
# 							Turkish (2)</option>
# <option label="Ukrainian (5)" value="454">
# 							Ukrainian (5)</option>
# <option label="Undetermined (4)" value="456">
# 							Undetermined (4)</option>
# <option label="Urdu (1)" value="457">
# 							Urdu (1)</option>
# <option label="Vietnamese (5)" value="461">
# 							Vietnamese (5)</option>
# <option label="Welsh (12)" value="468">
# 							Welsh (12)</option>
# </select>
# </div>
# <div class="form-group">
# <label for="">Format</label>
# <select class="form-control" id="filterFormat" name="format">
# <option label="All" value="">
# 							All</option>
# <option label="Paperback" value="1">
# 							Paperback</option>
# <option label="Hardback" value="2">
# 							Hardback</option>
# <option label="Audio" value="3">
# 							Audio</option>
# <option label="Baby Books" value="4">
# 							Baby Books</option>
# <option label="Digital" value="5">
# 							Digital</option>
# <option label="Maps" value="6">
# 							Maps</option>
# <option label="Stationery" value="7">
# 							Stationery</option>
# <option label="Toys" value="8">
# 							Toys</option>
# </select>
# </div>
# <div class="form-group padded-btn-wrap">
# <button class="btn btn-primary" type="submit">
# 					Refine results</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="main-content bestseller-page">
# <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filter your search">Filter your search</a>
# <h1>Bestsellers – our most popular items, updated daily.</h1>
# <div class="head-block">
# <div class="search-info left-content" id="search-info">
#                 Showing 1 to 30 of <span class="search-count">1,000</span> results</div>
# <div class="right-content">
# <ul class="pagination pagination-sm responsive-pagination">
# <li class="active"><a>1</a></li>
# <li><a href="/bestsellers?page=2">2</a></li>
# <li><a href="/bestsellers?page=3">3</a></li>
# <li><a href="/bestsellers?page=4">4</a></li>
# <li><a href="/bestsellers?page=5">5</a></li>
# <li class="next" id="next-top"><a href="/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# <div class="content-block">
# <div class="block-wrap search no-heading">
# <div class="block">
# <div class="tab-wrap module type-book grid tab--2 tab-active">
# <div class="tab">
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
# <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
# </a>
# </div>
# <meta content="9781471156267" itemprop="isbn"/>
# <meta content="It Ends With Us: The most heartbreaking novel you'll ever read" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                     It Ends With Us: The most heartbreaking novel you'll ever read<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">02 Aug 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,07 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="14.07" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Verity-Colleen-Hoover/9781408726600" itemprop="url">
# <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
# </a>
# </div>
# <meta content="9781408726600" itemprop="isbn"/>
# <meta content="Verity" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Verity-Colleen-Hoover/9781408726600">
#                     Verity<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Verity" href="/Verity-Colleen-Hoover/9781408726600">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">20 Jan 2022</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,20 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="14.2" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Love-Hypothesis-Ali-Hazelwood/9781408725764" itemprop="url">
# <img alt="The Love Hypothesis" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408725764.jpg"/>
# </a>
# </div>
# <meta content="9781408725764" itemprop="isbn"/>
# <meta content="The Love Hypothesis" itemprop="name"/>
# <meta content="Ali Hazelwood" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Love-Hypothesis-Ali-Hazelwood/9781408725764">
#                     The Love Hypothesis<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Ali-Hazelwood" itemprop="author">Ali Hazelwood</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Love Hypothesis" href="/Love-Hypothesis-Ali-Hazelwood/9781408725764">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Oct 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,32 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408725764" data-price="14.32" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408725764" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Manifest-Roxie-Nafousi/9780241539590" itemprop="url">
# <img alt="Manifest" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2415/9780241539590.jpg"/>
# </a>
# </div>
# <meta content="9780241539590" itemprop="isbn"/>
# <meta content="Manifest" itemprop="name"/>
# <meta content="Roxie Nafousi" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Manifest-Roxie-Nafousi/9780241539590">
#                     Manifest<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Roxie-Nafousi" itemprop="author">Roxie Nafousi</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Manifest" href="/Manifest-Roxie-Nafousi/9780241539590">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">06 Jan 2022</p>
# <p class="format">Hardback</p>
# <div class="price-wrap">
# <p class="price">
#                         21,14 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241539590" data-price="21.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241539590" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
# <img alt="Seven Husbands of Evelyn Hugo" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
# </a>
# </div>
# <meta content="9781398515697" itemprop="isbn"/>
# <meta content="Seven Husbands of Evelyn Hugo" itemprop="name"/>
# <meta content="Taylor Jenkins Reid" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                     Seven Husbands of Evelyn Hugo<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">14 Oct 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,14 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515697" data-price="14.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Ugly-Love-Colleen-Hoover/9781471136726" itemprop="url">
# <img alt="Ugly Love" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471136726.jpg"/>
# </a>
# </div>
# <meta content="9781471136726" itemprop="isbn"/>
# <meta content="Ugly Love" itemprop="name"/>
# <meta content="Colleen Hoover" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Ugly-Love-Colleen-Hoover/9781471136726">
#                     Ugly Love<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Ugly Love" href="/Ugly-Love-Colleen-Hoover/9781471136726">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">21 Jan 2016</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,46 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471136726" data-price="14.46" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471136726" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Spanish-Love-Deception-Elena-Armas/9781398515628" itemprop="url">
# <img alt="The Spanish Love Deception" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515628.jpg"/>
# </a>
# </div>
# <meta content="9781398515628" itemprop="isbn"/>
# <meta content="The Spanish Love Deception" itemprop="name"/>
# <meta content="Elena Armas" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Spanish-Love-Deception-Elena-Armas/9781398515628">
#                     The Spanish Love Deception<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Elena-Armas" itemprop="author">Elena Armas</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Spanish Love Deception" href="/Spanish-Love-Deception-Elena-Armas/9781398515628">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">28 Oct 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,40 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515628" data-price="14.4" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515628" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Midnight-Library-Matt-Haig/9781786892737" itemprop="url">
# <img alt="The Midnight Library" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7868/9781786892737.jpg"/>
# </a>
# </div>
# <meta content="9781786892737" itemprop="isbn"/>
# <meta content="The Midnight Library" itemprop="name"/>
# <meta content="Matt Haig" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Midnight-Library-Matt-Haig/9781786892737">
#                     The Midnight Library<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Matt-Haig" itemprop="author">Matt Haig</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Midnight Library" href="/Midnight-Library-Matt-Haig/9781786892737">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">18 Feb 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         13,02 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786892737" data-price="13.02" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786892737" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501" itemprop="url">
# <img alt="Sing Backwards and Weep" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4746/9781474615501.jpg"/>
# </a>
# </div>
# <meta content="9781474615501" itemprop="isbn"/>
# <meta content="Sing Backwards and Weep" itemprop="name"/>
# <meta content="Mark Lanegan" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501">
#                     Sing Backwards and Weep<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Mark-Lanegan" itemprop="author">Mark Lanegan</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Sing Backwards and Weep" href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">01 Apr 2021</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         14,24 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781474615501" data-price="14.24" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781474615501" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Fine-Print-Lauren-Asher/9780349433448" itemprop="url">
# <img alt="The Fine Print" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349433448.jpg"/>
# </a>
# </div>
# <meta content="9780349433448" itemprop="isbn"/>
# <meta content="The Fine Print" itemprop="name"/>
# <meta content="Lauren Asher" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Fine-Print-Lauren-Asher/9780349433448">
#                     The Fine Print<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Lauren-Asher" itemprop="author">Lauren Asher</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Fine Print" href="/Fine-Print-Lauren-Asher/9780349433448">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">27 Jan 2022</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         13,00 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# ...
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Psychology-Money-Morgan-Housel/9780857197689" itemprop="url">
# <img alt="The Psychology of Money" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8571/9780857197689.jpg"/>
# </a>
# </div>
# <meta content="9780857197689" itemprop="isbn"/>
# <meta content="The Psychology of Money" itemprop="name"/>
# <meta content="Morgan Housel" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Psychology-Money-Morgan-Housel/9780857197689">
#                     The Psychology of Money<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Morgan-Housel" itemprop="author">Morgan Housel</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Psychology of Money" href="/Psychology-Money-Morgan-Housel/9780857197689">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">08 Sep 2020</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         19,09 €
#                              <span class="rrp">19,50 €</span>
# </p>
# <p class="price-save">
# <span>
#                                 Save 0,41 €</span>
# <a class="price-save-link" href="/help/topic/HelpId/RRP#helpContent">
#                                     vs RRP</a>
# </p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780857197689" data-price="19.09" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780857197689" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611" itemprop="url">
# <img alt="The Body Keeps the Score" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141978611.jpg"/>
# </a>
# </div>
# <meta content="9780141978611" itemprop="isbn"/>
# <meta content="The Body Keeps the Score" itemprop="name"/>
# <meta content="Bessel van der Kolk" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#                     The Body Keeps the Score<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Bessel-van-der-Kolk" itemprop="author">Bessel van der Kolk</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Body Keeps the Score" href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">24 Sep 2015</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         17,94 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141978611" data-price="17.94" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780141978611" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# <div class="book-item" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-img">
# <a href="/Hating-Game-Sally-Thorne/9780349414263" itemprop="url">
# <img alt="The Hating Game" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349414263.jpg"/>
# </a>
# </div>
# <meta content="9780349414263" itemprop="isbn"/>
# <meta content="The Hating Game" itemprop="name"/>
# <meta content="Sally Thorne" itemprop="contributor"/>
# <div class="item-info">
# <h3 class="title">
# <a href="/Hating-Game-Sally-Thorne/9780349414263">
#                     The Hating Game<br/>
# </a>
# </h3>
# <p class="author">
# <a href="/author/Sally-Thorne" itemprop="author">Sally Thorne</a>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for The Hating Game" href="/Hating-Game-Sally-Thorne/9780349414263">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">07 Sep 2017</p>
# <p class="format">Paperback</p>
# <div class="price-wrap">
# <p class="price">
#                         12,58 €</p>
# </div>
# </div>
# <div class="item-actions">
# <div class="btn-wrap">
# <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349414263" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780349414263" rel="nofollow">
#                         Add to basket</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script></div>
# <div class="foot-block">
# <div class="right-content">
# <ul class="pagination pagination-sm">
# <li class="active"><a>1</a></li>
# <li><a href="/bestsellers?page=2">2</a></li>
# <li><a href="/bestsellers?page=3">3</a></li>
# <li><a href="/bestsellers?page=4">4</a></li>
# <li><a href="/bestsellers?page=5">5</a></li>
# <li class="next" id="next-bottom"><a href="/bestsellers?page=2">»</a></li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="footer-top"> <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/newsletter/add">
# <div class="form-group">
# <input aria-label="Email address for newsletter subscription" class="form-control" name="newsletterEmailAddress" placeholder="Email address" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div></div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>Follow us</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Explore</h4>
# <ul>
# <li><a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                         About us</a></li>
# <li><a href="/sitemap">
#                         Sitemap</a></li>
# <li><a href="/bookmarks">
#                         Bookmarks</a></li>
# <li><a class="footer-sign-in-link" href="/account/login/to/account">
#                                 Sign in/Join</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>How can we help?</h4>
# <ul>
# <li>
# <a href="/help" rel="nofollow">
#                             Help</a>
# </li>
# <li>
# <a href="/contactus">
#                             Contact us</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                             Where's my stuff?</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                             Where do you deliver?</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Join us</h4>
# <ul>
# <li><a href="/affiliate">
#                         Affiliates</a></li>
# <li><a href="/jobs">
#                         Jobs</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Important stuff</h4>
# <ul>
# <li>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                             Cookies</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                             Privacy policy</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                             Terms &amp; Conditions</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                 Sign in/Join</a></li>
# <li><a href="/track">
#                         Order Status</a></li>
# <li><a href="/contactus">
#                         Contact us</a></li>
# <li><a href="/help">
#                         Help</a></li>
# <li><a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                         About us</a></li>
# <li><a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                         Terms &amp; Conditions</a></li>
# <li><a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                         Privacy policy</a></li>
# <li><a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                         Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>We accept these payment methods </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2018-1', requestTime='0.06 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='213.99.35.27', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Mar 01 09:25:14 UTC 2022, cacheEnabled=true}}">
#                     © 2022
#                     The Book Depository Ltd.UK.<br/>Registered company number: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#     window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/js/app.js";
# </script>
# <script type="text/javascript">
#     csmWidgetStart('firstload-js-download');
# </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Shop","bd_js_too_long_for_shipping_label":"Sorry, that's too long for our shipping labels","bd_js_too_long":"Sorry, that's too long","bd_js_could_not_find_address_try_again":"Sorry, we couldn't find the address. Please try again","bd_saving_percent_off":"{0}%&lt;br&gt;off","bd_js_total_basket_count":"{0, plural, one {You have &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;item&lt;/span&gt;&lt;/b&gt; in your basket} other {You have &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;items&lt;/span&gt;&lt;/b&gt; in your basket}}","bd_js_total_cost":"Total cost: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"show less","bd_js_item_added_to_your_basket":"Item added to your basket","bd_link_prefix":"","bd_js_unable_get_address_enter_manually":"Sorry, we are unable to get the address. Please enter manually:","bd_js_keep_typing_to_refine_search_results":"Keep typing to refine the search results","bd_js_top_categories":"Top Categories","bd_price_save":"Save {0}","bd_js_name_only_letters":"Sorry, full name can only contain letters","bd_js_show_more":"show more","bd_js_enter_valid_email_address":"Please enter a valid email address","bd_js_enter_address_manually":"Enter address manually","bd_js_more_categories":"More Categories","bd_js_continue_shopping":"Continue Shopping","bd_js_account_and_help":"Account &amp; Help","bd_js_basket_checkout":"Basket / Checkout","bd_add_to_basket":"Add to basket","bd_js_enter_first_last_name":"Please enter a first and last name","bd_js_please_enter_your":"Please enter your"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# ![image](img\html-content-web-scraping.png)

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# ![image](img\attribute-example-for-web-scraping-1536x386.png)

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>
# 	Bestselling books online with free delivery at Book Depository</title>

# %%
soup.h1
# Out:
# <h1>Bestsellers – our most popular items, updated daily.</h1>

# %% [markdown]
# Y sí queremos solo el texto?..

# %%
soup.h1.get_text()
# Out:
# 'Bestsellers – our most popular items, updated daily.'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
soup.a['href']
# Out:
# '/help/topic/HelpId/53/How-we-use-cookies#helpContent'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar .find()")
print(soup.h1)
print("Utilizando .find()")
print(soup.find("h1"))
# Out:
# Sin utilizar .find()
# <h1>Bestsellers – our most popular items, updated daily.</h1>
# Utilizando .find()
# <h1>Bestsellers – our most popular items, updated daily.</h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a>,
#  <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                  Yes</a>,
#  <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                  Manage cookies</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a>,
#  <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a>,
#  <a class="showLess" role="button">Show less</a>,
#  <a class="showMore" role="button">Show more</a>,
#  <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                  Cancel</a>,
#  <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                  Save settings</a>,
#  <a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a>,
#  <a href="/contactus"><i class="icon-em"></i>Contact us</a>,
#  <a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a>,
#  <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#  <i class="icon-rocket"></i> Free delivery worldwide</a>,
#  <a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a>,
#  <a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a>,
#  <a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a>,
#  <a class="brand-link" href="/">
#  <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/logo.svg"/>
#  </a>,
#  <a class="mobile-basket-btn basket-wrap" href="/basket">
#  <span class="item-count" data-item-count="0">0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>,
#  <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
#  <i class="icon-rocket"></i> Free delivery worldwide</a>,
#  <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Free delivery worldwide">
#  <i class="icon-rocket"></i> Free delivery worldwide</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>,
#  <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>,
#  <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>,
#  <a>Browse All</a>,
#  <a href="/category/2/Art-Photography">
#                                      Art &amp; Photography</a>,
#  <a href="/category/3389/Audio-Books">
#                                      Audio Books</a>,
#  <a href="/category/213/Biography">
#                                      Biography</a>,
#  <a href="/category/928/Business-Finance-Law">
#                                      Business, Finance &amp; Law</a>,
#  <a href="/category/2455/Childrens-Books">
#                                      Children's Books</a>,
#  <a href="/category/1897/Computing">
#                                      Computing</a>,
#  <a href="/category/2942/Crafts-Hobbies">
#                                      Crafts &amp; Hobbies</a>,
#  <a href="/category/2616/Crime-Thriller">
#                                      Crime &amp; Thriller</a>,
#  <a href="/category/240/Dictionaries-Languages">
#                                      Dictionaries &amp; Languages</a>,
#  <a href="/category/3245/Entertainment">
#                                      Entertainment</a>,
#  <a href="/category/333/Fiction">
#                                      Fiction</a>,
#  <a href="/category/2858/Food-Drink">
#                                      Food &amp; Drink</a>,
#  <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                      Graphic Novels, Anime &amp; Manga</a>,
#  <a href="/category/2770/Health">
#                                      Health</a>,
#  <a href="/category/2638/History-Archaeology">
#                                      History &amp; Archaeology</a>,
#  <a href="/category/2892/Home-Garden">
#                                      Home &amp; Garden</a>,
#  <a href="/category/2978/Humour">
#                                      Humour</a>,
#  <a href="/category/1279/Medical">
#                                      Medical</a>,
#  <a href="/category/2819/Mind-Body-Spirit">
#                                      Mind, Body &amp; Spirit</a>,
#  <a href="/category/2985/Natural-History">
#                                      Natural History</a>,
#  <a href="/category/2802/Personal-Development">
#                                      Personal Development</a>,
#  <a href="/category/283/Poetry-Drama">
#                                      Poetry &amp; Drama</a>,
#  <a href="/category/375/Reference">
#                                      Reference</a>,
#  <a href="/category/3120/Religion">
#                                      Religion</a>,
#  <a href="/category/2630/Romance">
#                                      Romance</a>,
#  <a href="/category/1476/Science-Geography">
#                                      Science &amp; Geography</a>,
#  <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                      Science Fiction, Fantasy &amp; Horror</a>,
#  <a href="/category/632/Society-Social-Sciences">
#                                      Society &amp; Social Sciences</a>,
#  <a href="/category/3013/Sport">
#                                      Sport</a>,
#  <a href="/category/3385/Stationery">
#                                      Stationery</a>,
#  <a href="/category/3328/Teaching-Resources-Education">
#                                      Teaching Resources &amp; Education</a>,
#  <a href="/category/1708/Technology-Engineering">
#                                      Technology &amp; Engineering</a>,
#  <a href="/category/3391/Teen-Young-Adult">
#                                      Teen &amp; Young Adult</a>,
#  <a href="/category/2967/Transport">
#                                      Transport</a>,
#  <a href="/category/3098/Travel-Holiday-Guides">
#                                      Travel &amp; Holiday Guides</a>,
#  <a href="/category/3392/Books-for-Ages-0-2">
#                            Ages 0-2</a>,
#  <a href="/category/3393/Books-for-Ages-3-5">
#                            Ages 3-5</a>,
#  <a href="/category/3394/Books-for-Ages-6-8">
#                            Ages 6-8</a>,
#  <a href="/category/3395/Books-for-Ages-9-11">
#                            Ages 9-11</a>,
#  <a href="/category/3391/Teen-Young-Adult">
#                            Teen &amp; Young Adult</a>,
#  <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
#  <div class="link-text">J. K. Rowling</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/roald-dahl">
#  <div class="link-text">Roald Dahl</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/julia-donaldson">
#  <div class="link-text">Julia Donaldson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/stephen-king">
#  <div class="link-text">Stephen King</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/david-walliams">
#  <div class="link-text">David Walliams</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
#  <div class="link-text">Dr. Seuss</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/andy-griffiths">
#  <div class="link-text">Andy Griffiths</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/James-Patterson">
#  <div class="link-text">James Patterson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
#  <div class="link-text">Sarah J. Maas</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/enid-blyton">
#  <div class="link-text">Enid Blyton</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/john-green">
#  <div class="link-text">John Green</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
#  <div class="link-text">Brandon Sanderson</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/popular-authors">
#  <div class="link-text">See all</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/harry-potter">
#  <div class="link-text">Harry Potter</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/game-of-thrones">
#  <div class="link-text">Game Of Thrones</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/lego">
#  <div class="link-text">Lego</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/divergent-trilogy">
#  <div class="link-text">Divergent</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
#  <div class="link-text">Throne Of Glass</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/star-wars">
#  <div class="link-text">Star Wars</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/spanish">
#  <div class="link-text">Books in Spanish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/polish-books">
#  <div class="link-text">Books in Polish</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/german-books">
#  <div class="link-text">Books in German</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/french-books">
#  <div class="link-text">Books in French</div>
#  </a>,
#  <a class="link-item-text-only link-item" href="/languages">
#  <div class="link-text">Languages Bookshop</div>
#  </a>,
#  <a href="/bestsellers">Bestsellers</a>,
#  <a href="/comingsoon">Coming Soon</a>,
#  <a href="/top-new-releases">New Releases</a>,
#  <a class="tbd-dropdown-toggle desktop-only" href="#">
#          English</a>,
#  <a class="global-nav-close" href="#"><i class="icon-close"></i></a>,
#  <a class="language-option" data-value="en_US" href="#">
#                              English</a>,
#  <a class="language-option" data-value="es_ES" href="#">
#                              Spanish (Español)</a>,
#  <a class="basket-btn" href="/basket" rel="nofollow">
#  <span class="item-count">
#                          0</span>
#  <i class="icon-basket"></i>
#  </a>,
#  <a class="modal-trigger sidebar-trigger" data-target=".search-filter-sidebar" data-title="Filter your search">Filter your search</a>,
#  <a>1</a>,
#  <a href="/bestsellers?page=2">2</a>,
#  <a href="/bestsellers?page=3">3</a>,
#  <a href="/bestsellers?page=4">4</a>,
#  <a href="/bestsellers?page=5">5</a>,
#  <a href="/bestsellers?page=2">»</a>,
#  <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267" itemprop="url">
#  <img alt="It Ends With Us: The most heartbreaking novel you'll ever read" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471156267.jpg"/>
#  </a>,
#  <a href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#                      It Ends With Us: The most heartbreaking novel you'll ever read<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for It Ends With Us: The most heartbreaking novel you'll ever read" href="/It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471156267" data-price="14.07" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471156267" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Verity-Colleen-Hoover/9781408726600" itemprop="url">
#  <img alt="Verity" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408726600.jpg"/>
#  </a>,
#  <a href="/Verity-Colleen-Hoover/9781408726600">
#                      Verity<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Verity" href="/Verity-Colleen-Hoover/9781408726600">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408726600" data-price="14.2" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408726600" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Love-Hypothesis-Ali-Hazelwood/9781408725764" itemprop="url">
#  <img alt="The Love Hypothesis" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4087/9781408725764.jpg"/>
#  </a>,
#  <a href="/Love-Hypothesis-Ali-Hazelwood/9781408725764">
#                      The Love Hypothesis<br/>
#  </a>,
#  <a href="/author/Ali-Hazelwood" itemprop="author">Ali Hazelwood</a>,
#  <a aria-label="Ratings for The Love Hypothesis" href="/Love-Hypothesis-Ali-Hazelwood/9781408725764">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408725764" data-price="14.32" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408725764" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Manifest-Roxie-Nafousi/9780241539590" itemprop="url">
#  <img alt="Manifest" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/2415/9780241539590.jpg"/>
#  </a>,
#  <a href="/Manifest-Roxie-Nafousi/9780241539590">
#                      Manifest<br/>
#  </a>,
#  <a href="/author/Roxie-Nafousi" itemprop="author">Roxie Nafousi</a>,
#  <a aria-label="Ratings for Manifest" href="/Manifest-Roxie-Nafousi/9780241539590">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780241539590" data-price="21.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780241539590" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697" itemprop="url">
#  <img alt="Seven Husbands of Evelyn Hugo" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515697.jpg"/>
#  </a>,
#  <a href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#                      Seven Husbands of Evelyn Hugo<br/>
#  </a>,
#  <a href="/author/Taylor-Jenkins-Reid" itemprop="author">Taylor Jenkins Reid</a>,
#  <a aria-label="Ratings for Seven Husbands of Evelyn Hugo" href="/Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515697" data-price="14.14" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515697" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Ugly-Love-Colleen-Hoover/9781471136726" itemprop="url">
#  <img alt="Ugly Love" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471136726.jpg"/>
#  </a>,
#  <a href="/Ugly-Love-Colleen-Hoover/9781471136726">
#                      Ugly Love<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Ugly Love" href="/Ugly-Love-Colleen-Hoover/9781471136726">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471136726" data-price="14.46" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471136726" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Spanish-Love-Deception-Elena-Armas/9781398515628" itemprop="url">
#  <img alt="The Spanish Love Deception" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/3985/9781398515628.jpg"/>
#  </a>,
#  <a href="/Spanish-Love-Deception-Elena-Armas/9781398515628">
#                      The Spanish Love Deception<br/>
#  </a>,
#  <a href="/author/Elena-Armas" itemprop="author">Elena Armas</a>,
#  <a aria-label="Ratings for The Spanish Love Deception" href="/Spanish-Love-Deception-Elena-Armas/9781398515628">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781398515628" data-price="14.4" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781398515628" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Midnight-Library-Matt-Haig/9781786892737" itemprop="url">
#  <img alt="The Midnight Library" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7868/9781786892737.jpg"/>
#  </a>,
#  <a href="/Midnight-Library-Matt-Haig/9781786892737">
#                      The Midnight Library<br/>
#  </a>,
#  <a href="/author/Matt-Haig" itemprop="author">Matt Haig</a>,
#  <a aria-label="Ratings for The Midnight Library" href="/Midnight-Library-Matt-Haig/9781786892737">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786892737" data-price="13.02" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786892737" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501" itemprop="url">
#  <img alt="Sing Backwards and Weep" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4746/9781474615501.jpg"/>
#  </a>,
#  <a href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501">
#                      Sing Backwards and Weep<br/>
#  </a>,
#  <a href="/author/Mark-Lanegan" itemprop="author">Mark Lanegan</a>,
#  <a aria-label="Ratings for Sing Backwards and Weep" href="/Sing-Backwards-Weep-Mark-Lanegan/9781474615501">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781474615501" data-price="14.24" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781474615501" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Fine-Print-Lauren-Asher/9780349433448" itemprop="url">
#  <img alt="The Fine Print" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349433448.jpg"/>
#  </a>,
#  <a href="/Fine-Print-Lauren-Asher/9780349433448">
#                      The Fine Print<br/>
#  </a>,
#  <a href="/author/Lauren-Asher" itemprop="author">Lauren Asher</a>,
#  <a aria-label="Ratings for The Fine Print" href="/Fine-Print-Lauren-Asher/9780349433448">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349433448" data-price="13.0" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780349433448" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Atomic-Habits-James-Clear/9781847941831" itemprop="url">
#  <img alt="Atomic Habits" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8479/9781847941831.jpg"/>
#  </a>,
#  <a href="/Atomic-Habits-James-Clear/9781847941831">
#                      Atomic Habits<br/>
#  </a>,
#  <a href="/author/James-Clear" itemprop="author">James Clear</a>,
#  <a aria-label="Ratings for Atomic Habits" href="/Atomic-Habits-James-Clear/9781847941831">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="price-save-link" href="/help/topic/HelpId/RRP#helpContent">
#                                      vs RRP</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781847941831" data-price="21.25" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781847941831" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" itemprop="url">
#  <img alt="Cain's Jawbone" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8001/9781800180796.jpg"/>
#  </a>,
#  <a href="/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796">
#                      Cain's Jawbone<br/>
#  </a>,
#  <a href="/author/Ernest-Powys-Mathers" itemprop="author">Ernest Powys Mathers</a>,
#  <a aria-label="Ratings for Cain's Jawbone" href="/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781800180796" data-price="13.39" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781800180796" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Terms-Conditions-Lauren-Asher/9780349433455" itemprop="url">
#  <img alt="Terms and Conditions" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349433455.jpg"/>
#  </a>,
#  <a href="/Terms-Conditions-Lauren-Asher/9780349433455">
#                      Terms and Conditions<br/>
#  </a>,
#  <a href="/author/Lauren-Asher" itemprop="author">Lauren Asher</a>,
#  <a aria-label="Ratings for Terms and Conditions" href="/Terms-Conditions-Lauren-Asher/9780349433455">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349433455" data-price="15.02" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780349433455" rel="nofollow">
#                          Pre-order</a>,
#  <a href="/Chainsaw-Man-Vol-1-Tatsuki-Fujimoto/9781974709939" itemprop="url">
#  <img alt="Chainsaw Man, Vol. 1" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9747/9781974709939.jpg"/>
#  </a>,
#  <a href="/Chainsaw-Man-Vol-1-Tatsuki-Fujimoto/9781974709939">
#                      Chainsaw Man, Vol. 1<br/>
#  </a>,
#  <a href="/author/Tatsuki-Fujimoto" itemprop="author">Tatsuki Fujimoto</a>,
#  <a aria-label="Ratings for Chainsaw Man, Vol. 1" href="/Chainsaw-Man-Vol-1-Tatsuki-Fujimoto/9781974709939">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary" href="/Chainsaw-Man-Vol-1-Tatsuki-Fujimoto/9781974709939" rel="nofollow">
#                            Notify me</a>,
#  <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581" itemprop="url">
#  <img alt="Before the Coffee Gets Cold" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5290/9781529029581.jpg"/>
#  </a>,
#  <a href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#                      Before the Coffee Gets Cold<br/>
#  </a>,
#  <a href="/author/Toshikazu-Kawaguchi" itemprop="author">Toshikazu Kawaguchi</a>,
#  <a aria-label="Ratings for Before the Coffee Gets Cold" href="/Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529029581" data-price="12.55" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529029581" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Song-Achilles-Madeline-Miller/9781408891384" itemprop="url">
#  <img alt="The Song of Achilles" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4088/9781408891384.jpg"/>
#  </a>,
#  <a href="/Song-Achilles-Madeline-Miller/9781408891384">
#                      The Song of Achilles<br/>
#  </a>,
#  <a href="/author/Madeline-Miller" itemprop="author">Madeline Miller</a>,
#  <a aria-label="Ratings for The Song of Achilles" href="/Song-Achilles-Madeline-Miller/9781408891384">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781408891384" data-price="13.59" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781408891384" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/November-9-Colleen-Hoover/9781471154621" itemprop="url">
#  <img alt="November 9" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471154621.jpg"/>
#  </a>,
#  <a href="/November-9-Colleen-Hoover/9781471154621">
#                      November 9<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for November 9" href="/November-9-Colleen-Hoover/9781471154621">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471154621" data-price="14.52" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471154621" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Confess-Colleen-Hoover/9781471148590" itemprop="url">
#  <img alt="Confess" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4711/9781471148590.jpg"/>
#  </a>,
#  <a href="/Confess-Colleen-Hoover/9781471148590">
#                      Confess<br/>
#  </a>,
#  <a href="/author/Colleen-Hoover" itemprop="author">Colleen Hoover</a>,
#  <a aria-label="Ratings for Confess" href="/Confess-Colleen-Hoover/9781471148590">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781471148590" data-price="14.0" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781471148590" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Melizs-Kitchen-Meliz-Berg/9781529109504" itemprop="url">
#  <img alt="Meliz's Kitchen" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5291/9781529109504.jpg"/>
#  <div class="savings-splat">
#                          8%<br/>off</div>
#  </a>,
#  <a href="/Melizs-Kitchen-Meliz-Berg/9781529109504">
#                      Meliz's Kitchen<br/>
#  </a>,
#  <a href="/author/Meliz-Berg" itemprop="author">Meliz Berg</a>,
#  <a class="price-save-link" href="/help/topic/HelpId/RRP#helpContent">
#                                      vs RRP</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529109504" data-price="29.64" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529109504" rel="nofollow">
#                          Pre-order</a>,
#  <a href="/Girl-Who-Fell-Beneath-Sea-Axie-Oh/9781529391695" itemprop="url">
#  <img alt="The Girl Who Fell Beneath the Sea" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/5293/9781529391695.jpg"/>
#  </a>,
#  <a href="/Girl-Who-Fell-Beneath-Sea-Axie-Oh/9781529391695">
#                      The Girl Who Fell Beneath the Sea<br/>
#  </a>,
#  <a href="/author/Axie-Oh" itemprop="author">Axie Oh</a>,
#  <a aria-label="Ratings for The Girl Who Fell Beneath the Sea" href="/Girl-Who-Fell-Beneath-Sea-Axie-Oh/9781529391695">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="price-save-link" href="/help/topic/HelpId/RRP#helpContent">
#                                      vs RRP</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781529391695" data-price="19.42" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781529391695" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Scum-Villains-Self-Saving-System-Ren-Zha-Fanpai-Zijiu-Xitong-Novel-Vol-2-Mo-Xiang-Tong-Xiu/9781648279225" itemprop="url">
#  <img alt="The Scum Villain's Self-Saving System: Ren Zha Fanpai Zijiu Xitong (Novel) Vol. 2" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/6482/9781648279225.jpg"/>
#  </a>,
#  <a href="/Scum-Villains-Self-Saving-System-Ren-Zha-Fanpai-Zijiu-Xitong-Novel-Vol-2-Mo-Xiang-Tong-Xiu/9781648279225">
#                      The Scum Villain's Self-Saving System: Ren Zha Fanpai Zijiu Xitong (Novel) Vol. 2<br/>
#  </a>,
#  <a href="/author/Mo-Xiang-Tong-Xiu" itemprop="author">Mo Xiang Tong Xiu</a>,
#  <a aria-label="Ratings for The Scum Villain's Self-Saving System: Ren Zha Fanpai Zijiu Xitong (Novel) Vol. 2" href="/Scum-Villains-Self-Saving-System-Ren-Zha-Fanpai-Zijiu-Xitong-Novel-Vol-2-Mo-Xiang-Tong-Xiu/9781648279225">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781648279225" data-price="21.16" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781648279225" rel="nofollow">
#                          Pre-order</a>,
#  <a href="/Flavourbomb-Belinda-MacDonald/9780143776468" itemprop="url">
#  <img alt="Flavourbomb" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1437/9780143776468.jpg"/>
#  </a>,
#  <a href="/Flavourbomb-Belinda-MacDonald/9780143776468">
#                      Flavourbomb<br/>
#  </a>,
#  <a href="/author/Belinda-MacDonald" itemprop="author">Belinda MacDonald</a>,
#  <a class="btn btn-sm btn-primary" href="/Flavourbomb-Belinda-MacDonald/9780143776468" rel="nofollow">
#                            Notify me</a>,
#  <a href="/Normal-People-Sally-Rooney/9780571334650" itemprop="url">
#  <img alt="Normal People" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/5713/9780571334650.jpg"/>
#  </a>,
#  <a href="/Normal-People-Sally-Rooney/9780571334650">
#                      Normal People<br/>
#  </a>,
#  <a href="/author/Sally-Rooney" itemprop="author">Sally Rooney</a>,
#  <a aria-label="Ratings for Normal People" href="/Normal-People-Sally-Rooney/9780571334650">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780571334650" data-price="13.53" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780571334650" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Chainsaw-Man-Vol-2-Tatsuki-Fujimoto/9781974709946" itemprop="url">
#  <img alt="Chainsaw Man, Vol. 2" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9747/9781974709946.jpg"/>
#  </a>,
#  <a href="/Chainsaw-Man-Vol-2-Tatsuki-Fujimoto/9781974709946">
#                      Chainsaw Man, Vol. 2<br/>
#  </a>,
#  <a href="/author/Tatsuki-Fujimoto" itemprop="author">Tatsuki Fujimoto</a>,
#  <a aria-label="Ratings for Chainsaw Man, Vol. 2" href="/Chainsaw-Man-Vol-2-Tatsuki-Fujimoto/9781974709946">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781974709946" data-price="13.37" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781974709946" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Where-Crawdads-Sing-Delia-Owens/9781472154668" itemprop="url">
#  <img alt="Where the Crawdads Sing" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/4721/9781472154668.jpg"/>
#  </a>,
#  <a href="/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#                      Where the Crawdads Sing<br/>
#  </a>,
#  <a href="/author/Delia-Owens" itemprop="author">Delia Owens</a>,
#  <a aria-label="Ratings for Where the Crawdads Sing" href="/Where-Crawdads-Sing-Delia-Owens/9781472154668">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781472154668" data-price="12.5" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781472154668" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Kiss-Quotient-Helen-Hoang/9781786496768" itemprop="url">
#  <img alt="The Kiss Quotient" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/7864/9781786496768.jpg"/>
#  </a>,
#  <a href="/Kiss-Quotient-Helen-Hoang/9781786496768">
#                      The Kiss Quotient<br/>
#  </a>,
#  <a href="/author/Helen-Hoang" itemprop="author">Helen Hoang</a>,
#  <a aria-label="Ratings for The Kiss Quotient" href="/Kiss-Quotient-Helen-Hoang/9781786496768">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9781786496768" data-price="12.92" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9781786496768" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Dowry-Blood-S-T-Gibson/9781916366930" itemprop="url">
#  <img alt="A Dowry of Blood" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/9163/9781916366930.jpg"/>
#  </a>,
#  <a href="/Dowry-Blood-S-T-Gibson/9781916366930">
#                      A Dowry of Blood<br/>
#  </a>,
#  <a href="/author/S-T-Gibson" itemprop="author">S T Gibson</a>,
#  <a aria-label="Ratings for A Dowry of Blood" href="/Dowry-Blood-S-T-Gibson/9781916366930">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary" href="/Dowry-Blood-S-T-Gibson/9781916366930" rel="nofollow">
#                            Notify me</a>,
#  <a href="/Psychology-Money-Morgan-Housel/9780857197689" itemprop="url">
#  <img alt="The Psychology of Money" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/8571/9780857197689.jpg"/>
#  </a>,
#  <a href="/Psychology-Money-Morgan-Housel/9780857197689">
#                      The Psychology of Money<br/>
#  </a>,
#  <a href="/author/Morgan-Housel" itemprop="author">Morgan Housel</a>,
#  <a aria-label="Ratings for The Psychology of Money" href="/Psychology-Money-Morgan-Housel/9780857197689">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="price-save-link" href="/help/topic/HelpId/RRP#helpContent">
#                                      vs RRP</a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780857197689" data-price="19.09" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780857197689" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611" itemprop="url">
#  <img alt="The Body Keeps the Score" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/1419/9780141978611.jpg"/>
#  </a>,
#  <a href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#                      The Body Keeps the Score<br/>
#  </a>,
#  <a href="/author/Bessel-van-der-Kolk" itemprop="author">Bessel van der Kolk</a>,
#  <a aria-label="Ratings for The Body Keeps the Score" href="/Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star half-star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780141978611" data-price="17.94" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780141978611" rel="nofollow">
#                          Add to basket</a>,
#  <a href="/Hating-Game-Sally-Thorne/9780349414263" itemprop="url">
#  <img alt="The Hating Game" class="lazy" data-lazy="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9780/3494/9780349414263.jpg"/>
#  </a>,
#  <a href="/Hating-Game-Sally-Thorne/9780349414263">
#                      The Hating Game<br/>
#  </a>,
#  <a href="/author/Sally-Thorne" itemprop="author">Sally Thorne</a>,
#  <a aria-label="Ratings for The Hating Game" href="/Hating-Game-Sally-Thorne/9780349414263">
#  <div class="stars">
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star full-star"></span>
#  <span class="star"></span>
#  </div>
#  </a>,
#  <a class="btn btn-sm btn-primary add-to-basket" data-currency="EUR" data-isbn="9780349414263" data-price="12.58" data-ref="grid-view" data-show-related="false" href="/basket/addisbn/isbn13/9780349414263" rel="nofollow">
#                          Add to basket</a>,
#  <a>1</a>,
#  <a href="/bestsellers?page=2">2</a>,
#  <a href="/bestsellers?page=3">3</a>,
#  <a href="/bestsellers?page=4">4</a>,
#  <a href="/bestsellers?page=5">5</a>,
#  <a href="/bestsellers?page=2">»</a>,
#  <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-fb"></i>
#  </a>,
#  <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-tw"></i>
#  </a>,
#  <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-pi"></i>
#  </a>,
#  <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
#  <i class="icon-in"></i>
#  </a>,
#  <a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                          About us</a>,
#  <a href="/sitemap">
#                          Sitemap</a>,
#  <a href="/bookmarks">
#                          Bookmarks</a>,
#  <a class="footer-sign-in-link" href="/account/login/to/account">
#                                  Sign in/Join</a>,
#  <a href="/help" rel="nofollow">
#                              Help</a>,
#  <a href="/contactus">
#                              Contact us</a>,
#  <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                              Where's my stuff?</a>,
#  <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                              Where do you deliver?</a>,
#  <a href="/affiliate">
#                          Affiliates</a>,
#  <a href="/jobs">
#                          Jobs</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                              Cookies</a>,
#  <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                              Privacy policy</a>,
#  <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                              Terms &amp; Conditions</a>,
#  <a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                  Sign in/Join</a>,
#  <a href="/track">
#                          Order Status</a>,
#  <a href="/contactus">
#                          Contact us</a>,
#  <a href="/help">
#                          Help</a>,
#  <a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                          About us</a>,
#  <a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                          Terms &amp; Conditions</a>,
#  <a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                          Privacy policy</a>,
#  <a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                          Cookies</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
# Out:
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a>
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Yes</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Manage cookies</a>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>
# <a class="showLess" role="button">Show less</a>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 30 libros con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - book titles
# - formats (paperback or hardback)
# - publication dates
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los titulos de los libros (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un libro y elegimos inspeccionar)

# %% [markdown]
# title

# %%
all_h3 = soup.find_all("h3", class_="")
for h3 in all_h3:
       print(h3.get_text(strip=True))

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en class**__**=”title” no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los formatos de los libros

# %% [markdown]
# Del paso anterior tenemos todos los títulos de libros de la página de los más vendidos. Pero, ¿qué sabemos acerca de sus formatos? ¿Hay más libros de tapa dura o tapa blanda?
#
# Averigüémoslo inspeccionando el elemento de formato de libro:

# %% [markdown]
# Como siempre inspeccionamos y buscamos el formato..

# %% [markdown]
# Y como queremos saber la cantidad de cada formato lo metemos en dataframe

# %% [markdown]
# div.item-info p.format

# %%
formats = soup.select("") # div y p son etiquetas donde se encuentran
formats_series = pd.Series(formats)
formats_series.value_counts()

# %% [markdown]
# ## Obtener las fechas de publicación (find_all + get_text)

# %% [markdown]
# Al igual que antes inspeccionamos....

# %% [markdown]
# published

# %%
dates = soup.find_all("p", class_="")
dates = [date.get_text()[-4:] for date in dates] #con esta list comprehension obtenemos solo el año
dates_series = pd.Series(dates)
dates_series.value_counts()

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %% [markdown]
# Inspeccionamos..

# %% [markdown]
# price

# %%
prices = soup.find_all("p", class_="")

# %%
print(prices)
# Out:
# [<p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. You can learn more about our use of cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a></p>, <p>We use cookies and similar tools that are necessary to enable you to make purchases, including those used by approved third parties (collectively, "cookies") for the purposes described below.
#      <br/>You can learn more about how we (plus approved third parties) use cookies and how to change your settings by visiting the <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>. The choices you make here will apply to your interaction with this service on this device.</p>, <p>All Categories</p>, <p></p>, <p>Children's books by age range</p>, <p>Languages</p>, <p>Learn about new offers and get more deals by joining our newsletter</p>, <p>We accept these payment methods </p>]

# %%
prices[0]
# Out:
# <p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. You can learn more about our use of cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a></p>

# %%
prices[5].get_text(strip=True).split(' ')
# Out:
# ['Languages']

# %%
final_prices = []
for price in prices:
      original_price = price.find("span", class_="rrp")
      if original_price:
             current_price = str(original_price.previousSibling).strip() # nos quedamos solo con el numero sin etiquetas
             current_price = float(current_price.split("€")[0].replace(",", ".")) # quitamos el signo de euro y reemplazamos la coma por el punto para que python lo reconozca con float
             final_prices.append(current_price)
      else:
             current_price = float(price.get_text(strip=True).split("€")[0].replace(",", "."))
             final_prices.append(current_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_15652/625369209.py in <module>
#       7              final_prices.append(current_price)
#       8       else:
# ----> 9              current_price = float(price.get_text(strip=True).split("€")[0].replace(",", "."))
#      10              final_prices.append(current_price)
#
# ValueError: could not convert string to float: 'Cookies are used to provide. analyse and improve our services; provide chat tools; and showyou relevant content on advertising. You can learn more about our use of cookieshere'

# %%
print(final_prices)

# %% [markdown]
# ## Recolectar información de un libro

# %% [markdown]
# Primero creamos un soup en la pagína 'principal'

# %%
libros = soup.find_all(class_='item-img')

# %% [markdown]
# Guardamos en una variable la url principal

# %%
url_principal = 'https://www.bookdepository.com/'

# %% [markdown]
# Creamos una lista con los urls de los libros

# %%
lista_URLs = []
for libro in libros:
    URL_libro = libro.find('a')['href']
    lista_URLs.append(url_principal+URL_libro)

lista_URLs
# Out:
# ['https://www.bookdepository.com//It-Ends-With-Us-most-heartbreaking-novel-youll-ever-read-Colleen-Hoover/9781471156267',
#  'https://www.bookdepository.com//Verity-Colleen-Hoover/9781408726600',
#  'https://www.bookdepository.com//Love-Hypothesis-Ali-Hazelwood/9781408725764',
#  'https://www.bookdepository.com//Manifest-Roxie-Nafousi/9780241539590',
#  'https://www.bookdepository.com//Seven-Husbands-Evelyn-Hugo-Taylor-Jenkins-Reid/9781398515697',
#  'https://www.bookdepository.com//Ugly-Love-Colleen-Hoover/9781471136726',
#  'https://www.bookdepository.com//Spanish-Love-Deception-Elena-Armas/9781398515628',
#  'https://www.bookdepository.com//Midnight-Library-Matt-Haig/9781786892737',
#  'https://www.bookdepository.com//Sing-Backwards-Weep-Mark-Lanegan/9781474615501',
#  'https://www.bookdepository.com//Fine-Print-Lauren-Asher/9780349433448',
#  'https://www.bookdepository.com//Atomic-Habits-James-Clear/9781847941831',
#  'https://www.bookdepository.com//Cains-Jawbone-Ernest-Powys-Mathers/9781800180796',
#  'https://www.bookdepository.com//Terms-Conditions-Lauren-Asher/9780349433455',
#  'https://www.bookdepository.com//Chainsaw-Man-Vol-1-Tatsuki-Fujimoto/9781974709939',
#  'https://www.bookdepository.com//Before-Coffee-Gets-Cold-Toshikazu-Kawaguchi/9781529029581',
#  'https://www.bookdepository.com//Song-Achilles-Madeline-Miller/9781408891384',
#  'https://www.bookdepository.com//November-9-Colleen-Hoover/9781471154621',
#  'https://www.bookdepository.com//Confess-Colleen-Hoover/9781471148590',
#  'https://www.bookdepository.com//Melizs-Kitchen-Meliz-Berg/9781529109504',
#  'https://www.bookdepository.com//Girl-Who-Fell-Beneath-Sea-Axie-Oh/9781529391695',
#  'https://www.bookdepository.com//Scum-Villains-Self-Saving-System-Ren-Zha-Fanpai-Zijiu-Xitong-Novel-Vol-2-Mo-Xiang-Tong-Xiu/9781648279225',
#  'https://www.bookdepository.com//Flavourbomb-Belinda-MacDonald/9780143776468',
#  'https://www.bookdepository.com//Normal-People-Sally-Rooney/9780571334650',
#  'https://www.bookdepository.com//Chainsaw-Man-Vol-2-Tatsuki-Fujimoto/9781974709946',
#  'https://www.bookdepository.com//Where-Crawdads-Sing-Delia-Owens/9781472154668',
#  'https://www.bookdepository.com//Kiss-Quotient-Helen-Hoang/9781786496768',
#  'https://www.bookdepository.com//Dowry-Blood-S-T-Gibson/9781916366930',
#  'https://www.bookdepository.com//Psychology-Money-Morgan-Housel/9780857197689',
#  'https://www.bookdepository.com//Body-Keeps-Score-Bessel-van-der-Kolk/9780141978611',
#  'https://www.bookdepository.com//Hating-Game-Sally-Thorne/9780349414263']

# %% [markdown]
# Vamos a analizar el url de un libro primero

# %%
# Hacemos un nuevo request para el primer libro: 
r = requests.get(lista_URLs[11])

# Creamos una sopa específica con la info de cada libro
soup_libro = bs(r.text, "lxml")

# %% [markdown]
# creamos un soup del primer libro

# %%
soup_libro
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="©2020 Book Depository Ltd." name="copyright"/>
# <meta content="Book Depository" name="author"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1" name="viewport"/>
# <meta content="ogOme2fCVYq3eJxsHzQiMuXsUIRVwYrtI2Xn-U1nNpc" name="google-site-verification"/>
# <meta content="D45E907CC9A963F78BD3129AAAAFE4F0" name="msvalidate.01"/>
# <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/> <meta content="Cain's Jawbone by Ernest Powys Mathers, 9781800180796, available at Book Depository with free delivery worldwide." name="description"/>
# <meta content="Ernest Powys Mathers" name="keywords"/>
# <meta content="30 days" name="Revisit-After"/>
# <meta content="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/mid/9781/8001/9781800180796.jpg" name="thumbnail"/>
# <link href="https://www.bookdepository.com/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" rel="canonical"/>
# <link href="https://www.bookdepository.com/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" hreflang="x-default" rel="alternate"/>
# <link href="https://www.bookdepository.com/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" hreflang="en" rel="alternate"/>
# <link href="https://www.bookdepository.com/es/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" hreflang="es" rel="alternate"/>
# <title>
# 	Cain's Jawbone : Ernest Powys Mathers : 9781800180796</title>
# <!-- Styles -->
# <link href="https://d3ogvdx946i4sr.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/apple-touch-icon-rebranded.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/css/common.css" onload="csmWidgetEnd('css-download');" rel="stylesheet"/>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/css/ie/common.css">
# <![endif]-->
# <script type="text/javascript">
#     csmWidgetStart('icons-download');
# </script>
# <link as="font" crossorigin="" href="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/fonts/bdicons.woff" onload="csmWidgetEnd('icons-download');" rel="preload" type="font/woff2"/>
# <script type="text/javascript">
#     csmWidgetStart('font-download');
# </script>
# <link href="https://fonts.googleapis.com/css?family=Roboto" onload="csmWidgetEnd('font-download');" rel="stylesheet"/>
# <script type="text/javascript">
#     csmWidgetStart('css-download');
# </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#     window.ga('create', 'UA-41807899-1', 'www.bookdepository.com', {
#         'allowLinker': true,
#         'storage': 'none'
#     });
#
#
#     function registerPageView() {
#         window.ga('send', 'pageview');
#     }
#     document.addEventListener("DOMContentLoaded", function() {
#         registerPageView();
#     });
# </script>
# </head>
# <body class="">
# <div class="cookie-consent">
# <div class="cookie-consent-content">
# <h2>We use cookies to improve this site</h2>
# <p>Cookies are used to provide, analyse and improve our services; provide chat tools; and show<br/>you relevant content on advertising. You can learn more about our use of cookies <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>here</a></p><h2>Are you happy to accept cookies?</h2>
# </div>
# <div class="cookie-consent-buttons">
# <a class="btn btn-sm btn-yes" href="#" rel="nofollow">
#                 Yes</a>
# <a class="btn btn-sm btn-grey btn-manage" href="#" rel="nofollow">
#                 Manage cookies</a>
# </div>
# </div>
# <div class="cookie-management">
# <div class="scrollable-content">
# <div class="cookie-management-content">
# <h2>Cookie Preferences</h2>
# <p>We use cookies and similar tools that are necessary to enable you to make purchases, including those used by approved third parties (collectively, "cookies") for the purposes described below.
#      <br/>You can learn more about how we (plus approved third parties) use cookies and how to change your settings by visiting the <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookies notice</a>. The choices you make here will apply to your interaction with this service on this device.</p></div>
# <div class="cookie-management-categories">
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Essential</h2>
# </div>
# <div class="cookie-management-category-description">
# <span>We use cookies to provide our services, </span>
# <div>
# <div class="additionalInfo wrapping-space"> for example, to keep track of items stored in your shopping basket, prevent fraudulent activity, improve the security of our services, keep track of your specific preferences (such as currency or language preferences), and display features, products and services that might be of interest to you. Because we use cookies to provide you our services, they cannot be disabled when used for these purposes.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Performance and Analytics</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="performanceCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to understand how customers use our services</span>
# <div>
# <div class="additionalInfo wrapping-space"> (for example, by measuring site visits) so we can make improvements.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# <div class="cookie-management-category">
# <div class="cookie-management-category-title">
# <h2>Advertising</h2>
# </div>
# <div class="cookie-management-category-check">
# <span class="is-enabled">ON</span>
# <span class="is-disabled shown">OFF</span>
# <label class="slider-area">
# <input id="advertisingCheckBox" type="checkbox"/>
# <span class="slider-button"></span>
# </label>
# </div>
# <div class="cookie-management-category-description">
# <span>If you agree, we will use cookies to complement your shopping experience, as described in our <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" target='"_blank"'>Cookie Notice</a></span>
# <div>
# <div class="additionalInfo wrapping-space"> and serve you certain types of ads relevant to your interests on Book Depository. This includes using third party cookies for the purpose of displaying and measuring ads (see the <a href="/help/topic/HelpId/72/Interest-based-ads#helpContent" target='"_blank"'>Interest-Based Ads</a> notice for how we use cookies in serving interest-based ads), measuring the effectiveness of ads, and as necessary for the third party to perform services on behalf of Book Depository.</div>
# <a class="showLess" role="button">Show less</a>
# </div>
# <a class="showMore" role="button">Show more</a>
# </div>
# </div>
# </div>
# </div>
# <div class="cookie-management-buttons">
# <a class="btn btn-sm btn-grey btn-cancel" href="#" rel="nofollow">
#                 Cancel</a>
# <a class="btn btn-sm btn-save-settings" href="#" rel="nofollow">
#                 Save settings</a>
# </div>
# </div>
# <div class="page-slide">
# <div class="user-nav-wrap">
# <div class="user-nav">
# <ul class="left-nav nav mobile-nav-content" data-order="1">
# <li><a class="home-icon-link" href="/"><i class="icon-home"></i><span class="show-non-desktop">Home</span></a></li>
# <li class="mob-nav-account"><a href="/contactus"><i class="icon-em"></i>Contact us</a></li>
# <li class="mob-nav-account"><a href="/help" rel="nofollow"><i class="icon-info"></i>Help</a></li>
# </ul>
# <div class="middle-nav">
# <div class="free-delivery">
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# <ul class="right-nav mobile-nav-content" data-order="3">
# <li class="mob-nav-account"><a href="/track" rel="nofollow"><i class="icon-order-status"></i>Order Status</a></li>
# <li class="mob-nav-account"><a href="/account/wishlist" rel="nofollow"><i class="icon-wishlist"></i>Wishlist</a></li>
# <li class="mob-nav-account"><a href="/account/login/to/account" rel="nofollow"><i class="icon-user"></i>Sign in/Join</a></li>
# </ul>
# </div>
# </div>
# <div class="header-wrap">
# <header class="header">
# <div class="non-desktop-header show-non-desktop"></div>
# <div class="primary-wrap">
# <button aria-label="Mobile menu" class="mobile-trigger"><i class="icon-menu"></i></button>
# <div class="brand-wrap">
# <a class="brand-link" href="/">
# <img alt="Bookdepository.com" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/logo.svg"/>
# </a>
# </div>
# <div class="copy-content" data-target=".right-section .basket-wrap"></div>
# <div class="mobile-basket-wrap basket">
# <a class="mobile-basket-btn basket-wrap" href="/basket">
# <span class="item-count" data-item-count="0">0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# <div class="search-wrap" data-url="//suggestions.bookdepository.com/suggestions">
# <form action="/search" id="book-search-form">
# <div class="el-wrap header-search-el-wrap">
# <input aria-label="Search for books by keyword / title / author / ISBN" class="text-input" name="searchTerm" placeholder="Search for books by keyword / title / author / ISBN" type="text" value=""/>
# <input name="search" type="hidden" value="Find book"/>
# <button aria-label="Search" class="header-search-btn" type="submit"><span class="text">Search</span></button>
# </div>
# </form>
# <a class="advanced-search" href="/search/advanced" rel="nofollow">Advanced Search</a>
# </div>
# <div class="free-delivery-wrap">
# <div class="free-delivery">
# <a alt="Free delivery worldwide" href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="ribbon-wrap">
# <div class="free-delivery-ribbon">
# <div class="free-delivery-ribbon-item">
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to" rel="nofollow" title="Free delivery worldwide">
# <i class="icon-rocket"></i> Free delivery worldwide</a>
# </div>
# </div>
# </div>
# <div class="secondary-header-wrap">
# <div class="secondary-header">
# <ul class="page-links mobile-nav-content" data-order="2">
# <li class="tbd-dropdown category-dropdown mob-nav-shop">
# <a class="tbd-dropdown-toggle desktop-only" href="#">Shop by category</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="category-dropdown-list" href="#">Categories</a>
# <a class="tbd-dropdown-toggle show-non-desktop" data-target="age-range-dropdown-list" href="#">Children's Age Ranges</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close desktop-only" href="#"><i class="icon-close"></i></a>
# <li class="tbd-dropdown-header desktop-only"><p>All Categories</p><p></p></li>
# <li class="tbd-dropdown-back show-non-desktop"><a>Browse All</a></li><li>
# </li><li>
# <ul class="category-dropdown-list vertical-dropdown-list">
# <li class="top-category" data-order="10">
# <a href="/category/2/Art-Photography">
#                                     Art &amp; Photography</a>
# </li>
# <li data-order="0">
# <a href="/category/3389/Audio-Books">
#                                     Audio Books</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/213/Biography">
#                                     Biography</a>
# </li>
# <li data-order="0">
# <a href="/category/928/Business-Finance-Law">
#                                     Business, Finance &amp; Law</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2455/Childrens-Books">
#                                     Children's Books</a>
# </li>
# <li data-order="0">
# <a href="/category/1897/Computing">
#                                     Computing</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2942/Crafts-Hobbies">
#                                     Crafts &amp; Hobbies</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2616/Crime-Thriller">
#                                     Crime &amp; Thriller</a>
# </li>
# <li data-order="0">
# <a href="/category/240/Dictionaries-Languages">
#                                     Dictionaries &amp; Languages</a>
# </li>
# <li data-order="0">
# <a href="/category/3245/Entertainment">
#                                     Entertainment</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/333/Fiction">
#                                     Fiction</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2858/Food-Drink">
#                                     Food &amp; Drink</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2633/Graphic-Novels-Anime-Manga">
#                                     Graphic Novels, Anime &amp; Manga</a>
# </li>
# <li data-order="0">
# <a href="/category/2770/Health">
#                                     Health</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2638/History-Archaeology">
#                                     History &amp; Archaeology</a>
# </li>
# <li data-order="0">
# <a href="/category/2892/Home-Garden">
#                                     Home &amp; Garden</a>
# </li>
# <li data-order="0">
# <a href="/category/2978/Humour">
#                                     Humour</a>
# </li>
# <li data-order="0">
# <a href="/category/1279/Medical">
#                                     Medical</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2819/Mind-Body-Spirit">
#                                     Mind, Body &amp; Spirit</a>
# </li>
# <li data-order="0">
# <a href="/category/2985/Natural-History">
#                                     Natural History</a>
# </li>
# <li data-order="0">
# <a href="/category/2802/Personal-Development">
#                                     Personal Development</a>
# </li>
# <li data-order="0">
# <a href="/category/283/Poetry-Drama">
#                                     Poetry &amp; Drama</a>
# </li>
# <li data-order="0">
# <a href="/category/375/Reference">
#                                     Reference</a>
# </li>
# <li data-order="0">
# <a href="/category/3120/Religion">
#                                     Religion</a>
# </li>
# <li data-order="0">
# <a href="/category/2630/Romance">
#                                     Romance</a>
# </li>
# <li data-order="0">
# <a href="/category/1476/Science-Geography">
#                                     Science &amp; Geography</a>
# </li>
# <li class="top-category" data-order="10">
# <a href="/category/2623/Science-Fiction-Fantasy-Horror">
#                                     Science Fiction, Fantasy &amp; Horror</a>
# </li>
# <li data-order="0">
# <a href="/category/632/Society-Social-Sciences">
#                                     Society &amp; Social Sciences</a>
# </li>
# <li data-order="0">
# <a href="/category/3013/Sport">
#                                     Sport</a>
# </li>
# <li data-order="0">
# <a href="/category/3385/Stationery">
#                                     Stationery</a>
# </li>
# <li data-order="0">
# <a href="/category/3328/Teaching-Resources-Education">
#                                     Teaching Resources &amp; Education</a>
# </li>
# <li data-order="0">
# <a href="/category/1708/Technology-Engineering">
#                                     Technology &amp; Engineering</a>
# </li>
# <li data-order="0">
# <a href="/category/3391/Teen-Young-Adult">
#                                     Teen &amp; Young Adult</a>
# </li>
# <li data-order="0">
# <a href="/category/2967/Transport">
#                                     Transport</a>
# </li>
# <li data-order="0">
# <a href="/category/3098/Travel-Holiday-Guides">
#                                     Travel &amp; Holiday Guides</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-header desktop-only"><p>Children's books by age range</p></li>
# <li>
# <ul class="age-range-dropdown-list">
# <li>
# <a href="/category/3392/Books-for-Ages-0-2">
#                           Ages 0-2</a>
# </li>
# <li>
# <a href="/category/3393/Books-for-Ages-3-5">
#                           Ages 3-5</a>
# </li>
# <li>
# <a href="/category/3394/Books-for-Ages-6-8">
#                           Ages 6-8</a>
# </li>
# <li>
# <a href="/category/3395/Books-for-Ages-9-11">
#                           Ages 9-11</a>
# </li>
# <li>
# <a href="/category/3391/Teen-Young-Adult">
#                           Teen &amp; Young Adult</a>
# </li>
# </ul>
# </li>
# <li class="tbd-dropdown-editableLinks">
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Top Authors</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6269 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/author/J-K-Rowling">
# <div class="link-text">J. K. Rowling</div>
# </a>
# <a class="link-item-text-only link-item" href="/roald-dahl">
# <div class="link-text">Roald Dahl</div>
# </a>
# <a class="link-item-text-only link-item" href="/julia-donaldson">
# <div class="link-text">Julia Donaldson</div>
# </a>
# <a class="link-item-text-only link-item" href="/stephen-king">
# <div class="link-text">Stephen King</div>
# </a>
# <a class="link-item-text-only link-item" href="/david-walliams">
# <div class="link-text">David Walliams</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Dr-Seuss">
# <div class="link-text">Dr. Seuss</div>
# </a>
# <a class="link-item-text-only link-item" href="/andy-griffiths">
# <div class="link-text">Andy Griffiths</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/James-Patterson">
# <div class="link-text">James Patterson</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Sarah-J-Maas">
# <div class="link-text">Sarah J. Maas</div>
# </a>
# <a class="link-item-text-only link-item" href="/enid-blyton">
# <div class="link-text">Enid Blyton</div>
# </a>
# <a class="link-item-text-only link-item" href="/john-green">
# <div class="link-text">John Green</div>
# </a>
# <a class="link-item-text-only link-item" href="/author/Brandon-Sanderson">
# <div class="link-text">Brandon Sanderson</div>
# </a>
# <a class="link-item-text-only link-item" href="/popular-authors">
# <div class="link-text">See all</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Bestselling Series</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-6270 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/harry-potter">
# <div class="link-text">Harry Potter</div>
# </a>
# <a class="link-item-text-only link-item" href="/game-of-thrones">
# <div class="link-text">Game Of Thrones</div>
# </a>
# <a class="link-item-text-only link-item" href="/lego">
# <div class="link-text">Lego</div>
# </a>
# <a class="link-item-text-only link-item" href="/divergent-trilogy">
# <div class="link-text">Divergent</div>
# </a>
# <a class="link-item-text-only link-item" href="/search/advanced?seriesId=478050">
# <div class="link-text">Throne Of Glass</div>
# </a>
# <a class="link-item-text-only link-item" href="/star-wars">
# <div class="link-text">Star Wars</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="block-wrap sidebar">
# <div class="block-header">
# <h2>Books By Language</h2>
# </div>
# <div class="block">
# <!-- View layer for tabs (carousels, etc.) - micro-service, non-BDI based -->
# <div class="tab-wrap module type-link grid tab-11793 tab-active">
# <div class="tab">
# <a class="link-item-text-only link-item" href="/spanish">
# <div class="link-text">Books in Spanish</div>
# </a>
# <a class="link-item-text-only link-item" href="/polish-books">
# <div class="link-text">Books in Polish</div>
# </a>
# <a class="link-item-text-only link-item" href="/german-books">
# <div class="link-text">Books in German</div>
# </a>
# <a class="link-item-text-only link-item" href="/french-books">
# <div class="link-text">Books in French</div>
# </a>
# <a class="link-item-text-only link-item" href="/languages">
# <div class="link-text">Languages Bookshop</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="mob-nav-shop"><a href="/bestsellers">Bestsellers</a></li>
# <li class="mob-nav-shop"><a href="/comingsoon">Coming Soon</a></li><li class="mob-nav-shop"><a href="/top-new-releases">New Releases</a></li>
# <li class="mob-nav-shop copy-content hidden-lg" data-target=".language-selector-wrap"></li>
# </ul>
# <div class="right-section">
# <div data-order="4">
# <div class="language-selector-wrap">
# <div class="tbd-dropdown mob-nav-shop desktop-only">
# <a class="tbd-dropdown-toggle desktop-only" href="#">
#         English</a>
# <ul class="tbd-dropdown-menu" hidden="">
# <a class="global-nav-close" href="#"><i class="icon-close"></i></a>
# <li>
# <ul class="language-list vertical-dropdown-list">
# <li class="tbd-dropdown-header"><p>Languages</p></li>
# <li>
# <a class="language-option" data-value="en_US" href="#">
#                             English</a>
# </li>
# <li>
# <a class="language-option" data-value="es_ES" href="#">
#                             Spanish (Español)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <form action="" class="show-non-desktop" method="post">
# <div class="language-selector mob-nav-shop" title="English">
# <select id="selectLanguage" name="selectLanguage">
# <option selected="selected" value="en_US">
#                     English</option>
# <option value="es_ES">
#                     Español</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# <div class="currency-selector-wrap mobile-nav-content" data-order="5">
# <form action="" method="post">
# <div class="currency-selector mob-nav-account" title="Euro">
# <select id="selectCurrency" name="selectCurrency">
# <option value="AUD">
# 					$ AUD</option>
# <option selected="selected" value="EUR">
# 					€ EUR</option>
# <option value="USD">
# 					$ USD</option>
# <option value="GBP">
# 					£ GBP</option>
# <option value="NZD">
# 					$ NZD</option>
# <option value="SGD">
# 					$ SGD</option>
# <option value="CAD">
# 					$ CAD</option>
# <option value="AED">
# 					AED</option>
# <option value="ARS">
# 					$ ARS</option>
# <option value="BGN">
# 					Лв. BGN</option>
# <option value="BRL">
# 					R$ BRL</option>
# <option value="CHF">
# 					SFr. CHF</option>
# <option value="CLP">
# 					$ CLP</option>
# <option value="COP">
# 					$ COP</option>
# <option value="CZK">
# 					Kč CZK</option>
# <option value="DKK">
# 					Kr DKK</option>
# <option value="EGP">
# 					E£ EGP</option>
# <option value="HKD">
# 					$ HKD</option>
# <option value="HUF">
# 					Ft HUF</option>
# <option value="IDR">
# 					Rp IDR</option>
# <option value="ILS">
# 					₪ ILS</option>
# <option value="INR">
# 					₹ INR</option>
# <option value="JPY">
# 					¥ JPY</option>
# <option value="KRW">
# 					￦ KRW</option>
# <option value="MXN">
# 					$ MXN</option>
# <option value="MYR">
# 					RM MYR</option>
# <option value="NOK">
# 					Kr NOK</option>
# <option value="PEN">
# 					S/ PEN</option>
# <option value="PHP">
# 					₱ PHP</option>
# <option value="PLN">
# 					zł PLN</option>
# <option value="QAR">
# 					QR QAR</option>
# <option value="RON">
# 					L RON</option>
# <option value="SAR">
# 					SAR</option>
# <option value="SEK">
# 					Kr SEK</option>
# <option value="THB">
# 					฿ THB</option>
# <option value="TRY">
# 					₺ TRY</option>
# <option value="TWD">
# 					$ TWD</option>
# <option value="UYU">
# 					$ UYU</option>
# <option value="ZAR">
# 					R ZAR</option>
# </select>
# </div>
# </form></div>
# <div class="basket-wrap">
# <span class="total">0,00 €</span>
# <a class="basket-btn" href="/basket" rel="nofollow">
# <span class="item-count">
#                         0</span>
# <i class="icon-basket"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="content-wrap">
# <div onclick="void(0);">
# <div class="main-content no-borders book-page full-width">
# <ol class="breadcrumb">
# <li>
# <a href="/">
#                         Home</a>
# </li>
# </ol>
# <div class="item-wrap" itemscope="" itemtype="http://schema.org/Book">
# <div class="item-block">
# <meta content="/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" itemprop="url"/>
# <span itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="http://schema.org/InStock" itemprop="availability"/>
# <meta content="http://schema.org/NewCondition" itemprop="itemCondition"/>
# </span>
# <div class="item-img">
# <i class="icon-mobile-zoom"></i>
# <div class="item-img-content">
# <img alt="Cain's Jawbone" class="book-img" itemprop="image" src="https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8001/9781800180796.jpg"/>
# </div>
# <div class="copy-content visible-md" data-target=".social-wrap"></div>
# </div>
# <div class="item-info">
# <h1 itemprop="name">Cain's Jawbone : A Novel Problem</h1>
# <div class="rating-wrap hidden-md" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <a href="#rating-distribution">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# </a>
# <span itemprop="ratingValue">
#                             4.11</span>
# <span class="rating-count">
#                             (142 ratings by Goodreads)
# </span>
# <meta content="142" itemprop="ratingCount"/>
# </div>
# <ul class="meta-info hidden-md">
# <li>Paperback</li>
# <li>
# <span itemprop="inLanguage" itemtype="http://schema.org/Language">
# <a href="/search/advanced?searchLang=123">English</a></span>
# </li>
# </ul>
# <div class="author-info hidden-md">
#                     By (author)
#
#                         <span itemprop="author" itemscope="Ernest Powys Mathers" itemtype="http://schema.org/Person">
# <a href="/author/Ernest-Powys-Mathers" itemprop="url">
# <span itemprop="name">
#                                     Ernest Powys Mathers</span>
# </a>
# </span>
# </div>
# <ul class="social-wrap hidden-xs hidden-sm hidden-md">
# <li class="label">Share</li>
# <li><a href="mailto:?subject=Sharing a book&amp;body=I saw this book at Book Depository and thought you might like it:%0D%0A%0D%0Ahttps://www.bookdepository.com/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796" target="_blank"><i class="icon-em"></i></a></li>
# <li><a href="/share/book?id=54291995&amp;service=facebook&amp;mess=book" target="_blank"><i class="icon-fb"></i></a></li>
# <li><a href="https://twitter.com/intent/tweet?text=I've+discovered+Cain's+Jawbone&amp;url=https%3a%2f%2fwww.bookdepository.com%2fCains-Jawbone-Ernest-Powys-Mathers%2f9781800180796&amp;via=bookdepository" target="_blank"><i class="icon-tw"></i></a></li>
# <li><a href="http://pinterest.com/pin/create/button/?url=https://www.bookdepository.com/Cains-Jawbone-Ernest-Powys-Mathers/9781800180796&amp;media=https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8001/9781800180796.jpg&amp;description=The-worlds-most-fiendishly-difficult-literary-puzzle" target="_blank"><i class="icon-pi"></i></a></li>
# </ul>
# </div>
# <div class="item-tools">
# <div class="checkout-tools">
# <div class="copy-content visible-md" data-target=".item-block .rating-wrap"></div>
# <div class="price-info-wrap">
# <div class="item-info-wrap">
# <div class="copy-content visible-md" data-target=".meta-info"></div>
# <div class="copy-content visible-md" data-target=".author-info"></div>
# <div class="price item-price-wrap hidden-xs hidden-sm">
# <span class="sale-price">13,39 €</span>
# </div>
# <div class="copy-content visible-md visible-xs visible-sm" data-target=".formats-wrap"></div>
# <div class="free-delivery-text">
# <i class="icon-rocket"></i>
# <p>Free delivery worldwide</p>
# </div>
# <div class="gst-disclaimer" id="brexit_no_fee_message">
# <i class="icon-check"></i>
# <p>Price includes VAT/import taxes for EU delivery</p>
# </div>
# <div class="availability-text">
# <i class="icon-check"></i>
# <div class="edd-availability-text">
# <p>Available. Expected delivery to Spain in 12-17 business days.</p>
# <br/>
# <a class="edd-help-page-link" href="/help/topic/HelpId/2/When-will-my-order-arrive" target="_blank">
#                                                                 Not ordering to Spain? Click <span class="edd-help-page-link-here">here.<span></span></span></a>
# <br/>
# </div>
# </div>
# </div>
# </div>
# <div class="btn-wrap">
# <div class="copy-content visible-xs visible-sm" data-target=".item-price-wrap"></div>
# <a class="btn btn-primary add-to-basket" data-currency="EUR" data-isbn="9781800180796" data-price="13.39" data-show-related="true" href="/basket/addisbn/isbn13/9781800180796">
#                                     Add to basket</a>
# <a class="btn btn-grey add-to-wishlist" data-isbn="9781800180796" href="/account/wishlistItemUpdate?mainAction=add&amp;isbn13=9781800180796" rel="nofollow">
#                             Add to wishlist</a>
# <div class="copy-content visible-xs visible-sm" data-target=".social-wrap"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="item-description">
# <h2>Description</h2>
# <div class="item-excerpt trunc" data-height="230" itemprop="description">
#
#                     Six murders. One hundred pages. Millions of possible combinations... but only one is correct. Can you solve Torquemada's murder mystery?<br/>
# <br/>
#                     In 1934, the Observer's cryptic crossword compiler, Edward Powys Mathers (aka Torquemada), released a novel that was simultaneously a murder mystery and the most fiendishly difficult literary puzzle ever written.<br/>
# <br/>
#                     The pages have been printed in an entirely haphazard order, but it is possible - through logic and intelligent reading - to sort the pages into the only correct order, revealing six murder victims and their respective murderers.<br/>
# <br/>
#                     Only three puzzlers have ever solved the mystery of Cain's Jawbone: do you have what it takes to join their ranks?<br/>
# <br/>
#                     Please note: this puzzle is extremely difficult and not for the faint-hearted.<br/>
# <a class="read-more">show more</a>
# </div>
# </div>
# <script type="text/javascript">
#   if (ue) {
#     uet('af');
#   }
# </script><div class="biblio-wrap">
# <div class="biblio-info-wrap">
# <h2 class="biblio-title">
#                     Product details</h2>
# <ul class="biblio-info">
# <li>
# <label>Format</label>
# <span>
#                                 Paperback
#                                     | <span itemprop="numberOfPages">100 pages
# </span>
# </span>
# </li>
# <li>
# <label>Dimensions</label>
# <span>
#                                 111
#                                     x 178
#                                     x 20.32mm
#
#                                     | 181.44g
#                                 </span>
# </li>
# <li>
# <label>Publication date</label>
# <span itemprop="datePublished">08 Jul 2021</span>
# </li>
# <li>
# <label>Publisher</label>
# <span itemprop="publisher" itemscope="Unbound" itemtype="http://schema.org/Organization">
# <a href="/publishers/Unbound" itemprop="url">
# <span itemprop="name">
#                                         Unbound</span>
# </a>
# </span>
# </li>
# <li>
# <label>Publication City/Country</label>
# <span>
#                                 London, United Kingdom</span>
# </li>
# <li>
# <label>Language</label>
# <span>
#                                 English</span>
# </li>
# <li>
# <label>ISBN10</label>
# <span>1800180799</span>
# </li>
# <li>
# <label>ISBN13</label>
# <span itemprop="isbn">9781800180796</span>
# </li>
# <li>
# <label>Bestsellers rank</label>
# <span>
#                                 12</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="detail-page-carousel-wrap">
# </div><div class="item-annotation-wrap" id="item-annotation">
# <div class="item-annotation">
# <h2>Review quote</h2>
# <div class="block text-block trunc" data-height="100">
#                             'If James Joyce and Agatha Christie had a literary love child, this would be it' Daily Telegraph<br/>
#                             'A unique hybrid of word puzzle and whodunnit' Literary Review<br/>
# <a class="read-more">show more</a>
# </div>
# </div>
# <div class="item-annotation">
# <h2>About Ernest Powys Mathers</h2>
# <div class="block text-block trunc" data-height="100">
#                             Edward Powys Mathers (1892 - 1939) introduced the cryptic crossword to Britain in 1924 through the pages of the Observer. Known as Torquemada, he was acknowledged as a brilliant translator and a critic specialising in crime fiction. In 1934 he published a selection of his puzzles under the title The Torquemada Puzzle Book - the final hundred pages of which contained the novel-cum-puzzle Cain's Jawbone.<br/>
# <br/>
#                             The book is being re-issued with the assistance of The Laurence Sterne Trust and Patrick Wildgust, the curator of Shandy Hall.<br/>
# <a class="read-more">show more</a>
# </div>
# </div>
# </div>
# <div class="rating-distribution-wrap">
# <div class="rating-distribution" id="rating-distribution">
# <h2>Rating details</h2>
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star"></span>
# </div>
# <span class="rating-count">
#                 142 ratings</span>
# <div itemprop="ratingValue">
#                 4.11 out of 5 stars</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         5</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="46.478873239436616"></span>
# </span>
#
#                     46% (66)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         4</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="30.28169014084507"></span>
# </span>
#
#                     30% (43)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         3</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="13.380281690140844"></span>
# </span>
#
#                     13% (19)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         2</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="7.042253521126761"></span>
# </span>
#
#                     7% (10)</div>
# <div class="rating-distribution-entry">
# <span class="rating-distribution-index">
#                         1</span>
# <span class="star full-star"></span>
# <span class="rating-distribution-bar-wrap">
# <span class="bar" data-percentage="2.8169014084507045"></span>
# </span>
#
#                     3% (4)</div>
# </div>
# </div><div class="ratings-credit-wrap">
# <div class="ratings-credit">
#                     Book ratings by <span id="goodreads-credit"> Goodreads</span></div>
# <div class="goodreads-credit-extended">
# <a class="exit-to-goodreads" href="/external/GR/57057750" target="_blank">Goodreads</a> is the world's largest site for readers with over 50 million reviews. We're featuring millions of their reader ratings on our book pages to help you find your new favourite book.<span class="goodreads-close">
#                         Close</span>
# <span class="goodreads-close-x">
#                          X</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-top"> <div class="newsletter-section">
# <div class="newsletter-widget">
# <div class="signup-text">
# <img alt="Sign up" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/newsletter-icon.svg"/>
# <p>Learn about new offers and get more deals by joining our newsletter</p>
# </div>
# <div class="newsletter-form">
# <form action="/newsletter/add">
# <div class="form-group">
# <input aria-label="Email address for newsletter subscription" class="form-control" name="newsletterEmailAddress" placeholder="Email address" type="email"/>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" type="submit">
#                 Sign up now</button>
# </div>
# </form>
# </div></div>
# </div></div>
# <div class="footer-social-wrap">
# <h4>Follow us</h4>
# <ul class="social-btns">
# <li>
# <a aria-label="Book Depository Facebook" href="http://www.facebook.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-fb"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Twitter" href="http://twitter.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-tw"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Pinterest" href="http://pinterest.com/bookdepository/" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-pi"></i>
# </a>
# </li>
# <li>
# <a aria-label="Book Depository Instagram" href="https://www.instagram.com/bookdepository" rel="nofollow noopener noreferrer" target="_blank">
# <i class="icon-in"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-wrap">
# <footer class="footer">
# <div class="footer-left-content hide-on-mobile">
# <section class="footer-links">
# <h4>Explore</h4>
# <ul>
# <li><a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                         About us</a></li>
# <li><a href="/sitemap">
#                         Sitemap</a></li>
# <li><a href="/bookmarks">
#                         Bookmarks</a></li>
# <li><a class="footer-sign-in-link" href="/account/login/to/account">
#                                 Sign in/Join</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>How can we help?</h4>
# <ul>
# <li>
# <a href="/help" rel="nofollow">
#                             Help</a>
# </li>
# <li>
# <a href="/contactus">
#                             Contact us</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/2/When-will-my-order-arrive#helpContent" rel="nofollow">
#                             Where's my stuff?</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/3/Which-countries-do-you-deliver-to#helpContent" rel="nofollow">
#                             Where do you deliver?</a>
# </li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Join us</h4>
# <ul>
# <li><a href="/affiliate">
#                         Affiliates</a></li>
# <li><a href="/jobs">
#                         Jobs</a></li>
# </ul>
# </section>
# <section class="footer-links">
# <h4>Important stuff</h4>
# <ul>
# <li>
# <a href="/help/topic/HelpId/53/How-we-use-cookies#helpContent" rel="nofollow">
#                             Cookies</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/20/Our-privacy-policy#helpContent" rel="nofollow">
#                             Privacy policy</a>
# </li>
# <li>
# <a href="/help/topic/HelpId/19/Terms-and-Conditions#helpContent" rel="nofollow">
#                             Terms &amp; Conditions</a>
# </li>
# </ul>
# </section>
# </div>
# <div class="footer-left-content show-only-mobile">
# <div class="footer-links">
# <ul>
# <li><a class="footer-sign-in-link" href="/account/login/to/account" rel="nofollow">
#                                 Sign in/Join</a></li>
# <li><a href="/track">
#                         Order Status</a></li>
# <li><a href="/contactus">
#                         Contact us</a></li>
# <li><a href="/help">
#                         Help</a></li>
# <li><a href="/help/topic/HelpId/35/About-us#helpContent" rel="nofollow">
#                         About us</a></li>
# <li><a href="/help/topic/HelpId/19/Terms-and-Conditions" rel="nofollow">
#                         Terms &amp; Conditions</a></li>
# <li><a href="/help/topic/HelpId/20/Our-privacy-policy" rel="nofollow">
#                         Privacy policy</a></li>
# <li><a href="/help/topic/HelpId/53/How-we-use-cookies" rel="nofollow">
#                         Cookies</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-right-content">
# <div class="payment-methods">
# <p>We accept these payment methods </p>
# <img alt="Payment methods" class="lazy" data-lazy="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/img/payment-options.png"/>
# </div>
# <div class="small-print">
# <i class="icon-bd"></i>
# <div class="text" id="copyright" title="BdiMetadata{webserver='web-bdi-2018-2', requestTime='0.04 sec', userSessionCurrencyCode='EUR', userSessionCountry='ES', userIp='213.99.35.27', cacheParams=BdiCacheMetadata{cacheCountry='null', cacheCurrency='null', controllerName='null', actionName='null', moduleName='null', serverScheme='null', cacheNamespace='null', cacheKey='null', generatedOn=Tue Mar 01 10:30:38 UTC 2022, cacheEnabled=true}}">
#                     © 2022
#                     The Book Depository Ltd.UK.<br/>Registered company number: 5124926</div>
# </div>
# </div>
# </footer>
# </div>
# <script>
#     window.appJsSrc = "https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/js/app.js";
# </script>
# <script type="text/javascript">
#     csmWidgetStart('firstload-js-download');
# </script>
# <script async="" crossorigin="anonymous" onload="csmWidgetEnd('firstload-js-download');" src="https://d3ogvdx946i4sr.cloudfront.net/assets/v2.25.14/js/firstload.js"></script>
# <script type="text/javascript">document.body.className += " js";</script>
# </div>
# <div hidden="" id="bd_js_translations">{"bd_js_shop":"Shop","bd_js_too_long_for_shipping_label":"Sorry, that's too long for our shipping labels","bd_js_too_long":"Sorry, that's too long","bd_js_could_not_find_address_try_again":"Sorry, we couldn't find the address. Please try again","bd_saving_percent_off":"{0}%&lt;br&gt;off","bd_js_total_basket_count":"{0, plural, one {You have &lt;b&gt;&lt;span class='item-count'&gt;1&lt;/span&gt; &lt;span class='item-text'&gt;item&lt;/span&gt;&lt;/b&gt; in your basket} other {You have &lt;b&gt;&lt;span class='item-count'&gt;#&lt;/span&gt; &lt;span class='item-text'&gt;items&lt;/span&gt;&lt;/b&gt; in your basket}}","bd_js_total_cost":"Total cost: &lt;b class='pink-text big total'&gt;{0}&lt;/b&gt;","bd_js_show_less":"show less","bd_js_item_added_to_your_basket":"Item added to your basket","bd_link_prefix":"","bd_js_unable_get_address_enter_manually":"Sorry, we are unable to get the address. Please enter manually:","bd_js_keep_typing_to_refine_search_results":"Keep typing to refine the search results","bd_js_top_categories":"Top Categories","bd_price_save":"Save {0}","bd_js_name_only_letters":"Sorry, full name can only contain letters","bd_js_show_more":"show more","bd_js_enter_valid_email_address":"Please enter a valid email address","bd_js_enter_address_manually":"Enter address manually","bd_js_more_categories":"More Categories","bd_js_continue_shopping":"Continue Shopping","bd_js_account_and_help":"Account &amp; Help","bd_js_basket_checkout":"Basket / Checkout","bd_add_to_basket":"Add to basket","bd_js_enter_first_last_name":"Please enter a first and last name","bd_js_please_enter_your":"Please enter your"}</div>
# <div id="trackingCodeStatus"></div>
# <!-- The first Confirmation flag is only present on order confirmation page -->
# <script async="" defer="defer" src="https://www.dwin1.com/5487.js" type="text/javascript"> </script>
# <script async="" defer="defer" type="text/javascript">
#         if(document.getElementById("trackingCodeStatus")) {
#             document.getElementById("trackingCodeStatus").classList.add("aWinJourneyTagTracked");
#         }
#     </script>
# <script type="text/javascript">
#     function loadZopim(path, caller) {
#         window.$zopim || (function(d, s) {
#             var z = window.$zopim = function(c) {
#                 z._.push(c);
#             };
#
#             var $ = z.s = d.createElement(s);
#             var e = d.getElementsByTagName(s)[0];
#             z.set = function(o) {
#                 z.set._.push(o);
#             };
#             z._ = [];
#             z.set._ = [];
#             $.async = !0;
#             $.setAttribute('charset', 'utf-8');
#             $.src = '//v2.zopim.com/?2idAW3AKZ28UUWgitXg7WMvt1MrRI4pX';
#             z.t = +new Date();
#             $.type = 'text/javascript';
#             e.parentNode.insertBefore($, e);
#         })(document, 'script');
#
#         $zopim(function() {
#             if (sessionStorage.getItem('showZopimHomepage') == null) {
#                 sessionStorage.setItem('showZopimHomepage', Math.floor(Math.random() * 101) < 60);
#             }
#
#             if (path.includes(caller.stringLocalizer.localizedLink('/contactus')) ||
#                 path.includes(caller.stringLocalizer.localizedLink('/help')) ||
#                 path.startsWith(caller.stringLocalizer.localizedLink('/help/topic/')) ||
#                 (path == caller.stringLocalizer.localizedLink('/') && sessionStorage.getItem('showZopimHomepage') == "true")) {
#
#                 $zopim.livechat.theme.setColor('#4C394E');
#
#                 var first_time = true;
#                 $zopim.livechat.setOnStatus(function(status) {
#
#                     if (!first_time) return;
#
#                     first_time = false;
#                     if (status == 'online') {
#                         $zopim.livechat.button.show();
#                     } else if ($zopim.livechat.isChatting() == "false") {
#                         $zopim.livechat.button.hide();
#                     }
#                 });
#
#                 $zopim.livechat.setOnChatStart(function() {
#                     if ($zopim.livechat.isChatting() == "true") {
#                         $zopim.livechat.window.show();
#                         $zopim.livechat.bubble.show();
#                     }
#                 });
#
#                 $zopim.livechat.window.onHide(function() {
#                     $zopim.livechat.button.show();
#                 });
#
#                 $zopim.livechat.window.onShow(function() {
#                     $zopim.livechat.window.show();
#                 });
#
#                 if ($zopim.livechat.window.getDisplay() == "true") {
#                     $zopim.livechat.hideAll();
#                 }
#
#             } else {
#                 $zopim.livechat.hideAll();
#             }
#
#         });
#     }
# </script></body>
# </html>

# %% [markdown]
# Obtenemos el titulo del libro

# %%
name = soup_libro.find('h1').text
print(name)
# Out:
# Cain's Jawbone : A Novel Problem

# %% [markdown]
# El rating

# %%
rating = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[5].text.split(' ')[-1].replace(',','.')
rating = float(rating)
rating
# Out:
# 4.11

# %% [markdown]
# Cantidad de votaciones para el rating

# %%
rating_count = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[-1].text.split(' ')[-4].replace('(','').replace('.','')
rating_count = int(rating_count)
rating_count
# Out:
# 142

# %% [markdown]
# Tipo de formato

# %%
formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text
formats
# Out:
# 'Paperback'

# %% [markdown]
# Autor

# %%
author1 = soup_libro.find(class_ = 'item-info')('span')[-1].text.split('\n                                    ')[-1]
author1
# Out:
# 'Ernest Powys Mathers'

# %%
author = soup_libro.find(class_ = 'item-annotation-wrap')('h2')[2].text[6:]
author
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_15652/2634897609.py in <module>
# ----> 1 author = soup_libro.find(class_ = 'item-annotation-wrap')('h2')[2].text[6:]
#       2 author
#
# IndexError: list index out of range

# %% [markdown]
# Precio

# %%
price = soup_libro.find(class_ = 'sale-price').text
price
# Out:
# '13,39 €'

# %% [markdown]
# Url de la portada

# %%
imagen = soup_libro.find(class_ = 'book-img')['src']
imagen
# Out:
# 'https://d1w7fb2mkkr3kw.cloudfront.net/assets/images/book/lrg/9781/8001/9781800180796.jpg'

# %% [markdown]
# Ahora lo automatizamos para hacer un web scraping

# %%
pages = np.arange(1, 2)
count = 1
lista_libros = []

for page in pages:
    
    URL = 'https://www.bookdepository.com/es/bestsellers?page=' + str(page)
    r = requests.get(URL)
    soup = bs(r.text, 'lxml')
    libros_grid = soup.find_all(class_='item-img')
    
    count_libro = 1 # para el print de seguimiento de descarga
    
    for libro in libros_grid:
        # Print de seguimiento de descarga:
        print('Libro {} de {}, pag {}/{}'.format(
            count_libro, len(libros_grid), page, len(pages)))

        URL_libro = libro.find('a')['href']
        r = requests.get('https://www.bookdepository.com/' + URL_libro)
        soup_libro = bs(r.text, 'lxml')
        
        id_libro = 'lb_' + str(count)
        
        name = soup_libro.find('h1').text   
        try:
            price = soup_libro.find(class_ = 'sale-price').text

        except:
            price = None

        try :
            author = soup_libro.find(class_ = 'item-annotation-wrap')('h2')[2].text[6:]

        except:
            author = soup_libro.find(class_ = 'item-info')('span')[-1].text.split('\n                                    ')[-1]

        formats = soup_libro.find(class_ = 'meta-info hidden-md')('li')[0].text

        try:
            rating = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[5].text.split(' ')[-1].replace(',','.')
            rating = float(rating)
        
        except:
            rating = None
        
        try:    
            rating_count = soup_libro.find(class_ = 'rating-wrap hidden-md')('span')[-1].text.split(' ')[-6].replace('(','').replace('.','')
            rating_count = int(rating_count)
        
        except:
            rating_count = None

        imagen = soup_libro.find(class_ = 'book-img')['src']

        data = {"id_libro": id_libro,
                "name": name,
                "price": price,
                "author": author,
                "format": formats,
                "rating": rating,
                "rating_count": rating_count,
                "imagen": imagen}

        lista_libros.append(data)
        
        # Pasamos al siguiente id
        count += 1
        count_libro += 1

# %% [markdown]
# ---------------

# %%
df = pd.DataFrame(lista_libros)
df
